# %% [markdown]
# <a href="https://colab.research.google.com/github/TIMEdilation584/JP_Loksatta_moving_hearts/blob/master/29_06_22_Argoversse_Forecast_unzipping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/  Othercomputers/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd argove1_motion_forecasting_v1.1/
# Out:
# /content/drive/MyDrive/argove1_motion_forecasting_v1.1

# %%
ls
# Out:
# forecasting_test_v1.1.tar.zip  forecasting_val_v1.1.tar.zip
# forecasting_val_v1.1.tar.gz    test_obs/

# %%
# !unzip forecasting_val_v1.1.tar.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: val/data/17645.csv
#   inflating: val/data/32111.csv
#   inflating: val/data/12100.csv
#   inflating: val/data/2802.csv
#   inflating: val/data/34715.csv
#   inflating: val/data/18386.csv
#   inflating: val/data/31402.csv
#   inflating: val/data/31132.csv
#   inflating: val/data/11347.csv
#   inflating: val/data/40744.csv
#   inflating: val/data/6292.csv
#   inflating: val/data/35797.csv
#   inflating: val/data/12521.csv
#   inflating: val/data/29153.csv
#   inflating: val/data/35105.csv
#   inflating: val/data/26458.csv
#   inflating: val/data/32006.csv
#   inflating: val/data/24451.csv
#   inflating: val/data/9437.csv
#   inflating: val/data/6533.csv
#   inflating: val/data/38320.csv
#   inflating: val/data/22072.csv
#   inflating: val/data/23845.csv
#   inflating: val/data/25681.csv
#   inflating: val/data/17853.csv
#   inflating: val/data/10444.csv
#   inflating: val/data/19714.csv
# ...
