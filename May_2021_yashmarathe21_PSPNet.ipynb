# %% [markdown]
# <a href="https://colab.research.google.com/github/TIMEdilation584/JP_Loksatta_moving_hearts/blob/master/May_yashmarathe21_PSPNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
from imutils import paths
from tqdm import tqdm
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
import datetime
from glob import glob
import IPython.display as display
from IPython.display import clear_output
import math
import time
from tensorflow.keras.layers import *
import warnings
warnings.filterwarnings('ignore')
# For more information about autotune:
# https://www.tensorflow.org/guide/data_performance#prefetching
AUTOTUNE = tf.data.experimental.AUTOTUNE
print(f'Tensorflow ver. {tf.__version__}')
# Out:
# Tensorflow ver. 2.4.1

# %%
# !pip install wandb

# %%
import wandb
from wandb.keras import WandbCallback

# !wandb login
# Out:
# wandb: Currently logged in as: github2020 (use `wandb login --relogin` to force relogin)

# %% [markdown]
# ## Loading the Dataset

# %%
# important for reproducibility
# this allows to generate the same random numbers
SEED = 42

# Dataset path
dataset_path = 'drive/My Drive/idd-lite/idd20k_lite/'
img_train = dataset_path + 'leftImg8bit/train/'
seg_train = dataset_path + 'gtFine/train/'

img_val = dataset_path + 'leftImg8bit/val/'
seg_val = dataset_path + 'gtFine/val/'

# %%
dataset_path = 'drive/My Drive/idd-lite/idd20k_lite/'
img_train = dataset_path + 'leftImg8bit/train/'
glob(img_train+'*/*_image.jpg')

# %%
mask_train = dataset_path + 'gtFine/train'
glob(mask_train+'*/*_label.jpg')
# Out:
# []

# %% [markdown]
# ## Data Preparation

# %%
# Image size that we are going to use
(HEIGHT,WIDTH) = (128,128)
# Our images are RGB (3 channels)
N_CHANNELS = 3
# Scene Parsing has 7 classes (0-6) + `not labeled`
N_CLASSES = 8

# %%
# Reference -> https://docs.python.org/2/library/glob.html
# The glob module finds all the pathnames matching a specified pattern according to the rules used by the Unix shell, 
# although results are returned in arbitrary order. 

TRAINSET_SIZE = len(glob(img_train+'*/*_image.jpg'))
print(f"The Training Dataset contains {TRAINSET_SIZE} images.")

VALSET_SIZE = len(glob(img_val+'*/*_image.jpg'))
print(f"The Validation Dataset contains {VALSET_SIZE} images.")
# Out:
# The Training Dataset contains 1403 images.
# The Validation Dataset contains 204 images.

# %%
def parse_image(img_path):
    """
    Load an image and its annotation (mask) and returning a dictionary.
    """
    # Reading the image
    image = tf.io.read_file(img_path)
    image = tf.image.decode_jpeg(image, channels=3)
    # For one Image path:
    # .../idd20k_lite/leftImg8bit/train/024541_image.jpg
    # Its corresponding annotation path is:
    # .../idd20k_lite/gtFine/train/024541_label.png
    mask_path = tf.strings.regex_replace(img_path, "leftImg8bit", "gtFine")
    mask_path = tf.strings.regex_replace(mask_path, "_image.jpg", "_label.png")
    # Reading the annotation file corresponding the image file
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    # In scene parsing, "not labeled" = 255
    # But it will mess with our N_CLASS = 7
    # Since 255 means the 255th class
    # Which doesn't exist
    mask = tf.where(mask==255, np.dtype('uint8').type(7), mask)
    # Note that we have to convert the new value (7)
    # With the same dtype than the tensor itself
    return {'image': image, 'segmentation_mask': mask}

# %%
# Reference -> https://www.tensorflow.org/api_docs/python/tf/data/Dataset#list_files
# tf.data.Dataset.list_files returns a dataset of all files matching one or more glob patterns.

train_dataset = tf.data.Dataset.list_files(img_train+'*/*_image.jpg', seed=SEED)
train_dataset = train_dataset.map(parse_image)

val_dataset = tf.data.Dataset.list_files(img_val+'*/*_image.jpg', seed=SEED)
val_dataset =val_dataset.map(parse_image)

# %%
# Reference -> https://www.tensorflow.org/api_docs/python/tf/cast
# Returns a Tensor same shape as given tensor and same type as dtype that is mentioned.

def normalize(input_image, input_mask):
    """
    Rescale the pixel values of the images between 0 and 1 compared to [0,255] originally.
    """
    input_image = tf.cast(input_image, tf.float32) / 255.0
    return input_image, input_mask

# %%
# Reference -> https://www.tensorflow.org/api_docs/python/tf/image/resize
# Resize images to the size specified

def load_image_train(datapoint):
    """
    Normalize and resize a train image and its annotation.
    Apply random transformations to an input dictionary containing a train image and its annotation.
    """
    input_image = tf.image.resize(datapoint['image'], (HEIGHT,WIDTH))
    input_mask = tf.image.resize(datapoint['segmentation_mask'], (HEIGHT,WIDTH))
    if tf.random.uniform(()) > 0.5:
        input_image = tf.image.flip_left_right(input_image)
        input_mask = tf.image.flip_left_right(input_mask)
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask

def load_image_test(datapoint):
    """
    Normalize and resize a test image and its annotation.
    Since this is for the test set, we don't need to apply any data augmentation technique.
    """
    input_image = tf.image.resize(datapoint['image'], (HEIGHT,WIDTH))
    input_mask = tf.image.resize(datapoint['segmentation_mask'], (HEIGHT,WIDTH))
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask

# %%
BATCH_SIZE = 16
BUFFER_SIZE = 1500
dataset = {"train": train_dataset, "val": val_dataset}

# %%
# Reference -> https://www.tensorflow.org/api_docs/python/tf/data/Dataset

# Preparing the Train dataset by applying dataset transformations
dataset['train'] = dataset['train'].map(load_image_train, num_parallel_calls=tf.data.experimental.AUTOTUNE)
dataset['train'] = dataset['train'].shuffle(buffer_size=BUFFER_SIZE, seed=SEED)
dataset['train'] = dataset['train'].repeat()
dataset['train'] = dataset['train'].batch(BATCH_SIZE)
dataset['train'] = dataset['train'].prefetch(buffer_size=AUTOTUNE)
print(dataset['train'])

# Preparing the Validation Dataset
dataset['val'] = dataset['val'].map(load_image_test)
dataset['val'] = dataset['val'].repeat()
dataset['val'] = dataset['val'].batch(BATCH_SIZE)
dataset['val'] = dataset['val'].prefetch(buffer_size=AUTOTUNE)
print(dataset['val'])
# Out:
# <PrefetchDataset shapes: ((None, 128, 128, 3), (None, 128, 128, 1)), types: (tf.float32, tf.float32)>
# <PrefetchDataset shapes: ((None, 128, 128, 3), (None, 128, 128, 1)), types: (tf.float32, tf.float32)>

# %%
import shutil
import tensorflow as tf
from tqdm import tqdm
from glob import glob

img_train = 'drive/My Drive/idd-lite/idd20k_lite/' + 'leftImg8bit/train/'
train_paths = glob(img_train+'*/*_image.jpg')

for i in tqdm(train_paths):
    img = i.split('/')[-1]
    shutil.copy(i,'drive/My Drive/idd-lite/idd20k_lite/'+img)
    mask_path = tf.strings.regex_replace(i, "leftImg8bit", "gtFine")
    mask_path = tf.strings.regex_replace(mask_path, "_image.jpg", "_label.png")
    mask = img.split('_')[0]+'_label.png'
    shutil.copy(mask_path.numpy(),'drive/My Drive/idd-lite/idd20k_lite/'+mask)
# Out:
#   0%|          | 0/1403 [00:00<?, ?it/s]
#
#
#   0%|          | 1/1403 [00:00<06:19,  3.69it/s]
#
#
#   0%|          | 2/1403 [00:00<06:09,  3.79it/s]
#
#
#   0%|          | 3/1403 [00:00<05:51,  3.99it/s]
#
#
#   0%|          | 4/1403 [00:00<05:52,  3.97it/s]
#
#
#   0%|          | 5/1403 [00:01<06:35,  3.54it/s]
#
#
#   0%|          | 6/1403 [00:01<06:32,  3.56it/s]
#
#
#   0%|          | 7/1403 [00:01<06:31,  3.57it/s]
#
#
#   1%|          | 8/1403 [00:02<06:43,  3.46it/s]
#
#
#   1%|          | 9/1403 [00:02<06:36,  3.51it/s]
#
#
#   1%|          | 10/1403 [00:02<06:23,  3.64it/s]
#
#
#   1%|          | 11/1403 [00:03<06:31,  3.56it/s]
#
#
#   1%|          | 12/1403 [00:03<06:00,  3.86it/s]
#
#
#   1%|          | 13/1403 [00:03<06:00,  3.85it/s]
#
#
#   1%|          | 14/1403 [00:03<05:50,  3.96it/s]
#
#
#   1%|          | 15/1403 [00:04<05:59,  3.86it/s]
#
#
#   1%|          | 16/1403 [00:04<06:01,  3.84it/s]
#
#
#   1%|          | 17/1403 [00:04<06:12,  3.72it/s]
#
#
#   1%|▏         | 18/1403 [00:04<06:19,  3.65it/s]
#
#
#   1%|▏         | 19/1403 [00:05<05:56,  3.88it/s]
#
#
#   1%|▏         | 20/1403 [00:05<05:45,  4.01it/s]
#
#
#   1%|▏         | 21/1403 [00:05<05:23,  4.27it/s]
#
#
#   2%|▏         | 22/1403 [00:05<05:48,  3.97it/s]
#
#
#   2%|▏         | 23/1403 [00:06<06:07,  3.75it/s]
#
#
#   2%|▏         | 24/1403 [00:06<06:09,  3.74it/s]
#
#
#   2%|▏         | 25/1403 [00:06<05:42,  4.02it/s]
#
#
#   2%|▏         | 26/1403 [00:06<06:05,  3.76it/s]
#
#
#   2%|▏         | 27/1403 [00:07<06:41,  3.43it/s]
#
#
#   2%|▏         | 28/1403 [00:07<08:21,  2.74it/s]
#
#
#   2%|▏         | 29/1403 [00:08<08:00,  2.86it/s]
#
#
#   2%|▏         | 30/1403 [00:08<07:46,  2.94it/s]
#
#
#   2%|▏         | 31/1403 [00:08<07:24,  3.09it/s]
#
#
#   2%|▏         | 32/1403 [00:08<06:58,  3.27it/s]
#
#
#   2%|▏         | 33/1403 [00:09<06:39,  3.43it/s]
#
#
#   2%|▏         | 34/1403 [00:09<07:09,  3.19it/s]
#
#
#   2%|▏         | 35/1403 [00:09<06:57,  3.28it/s]
#
#
#   3%|▎         | 36/1403 [00:10<06:50,  3.33it/s]
#
#
#   3%|▎         | 37/1403 [00:10<06:28,  3.52it/s]
#
#
#   3%|▎         | 38/1403 [00:10<06:11,  3.67it/s]
#
#
#   3%|▎         | 39/1403 [00:11<07:02,  3.23it/s]
#
#
#   3%|▎         | 40/1403 [00:11<07:07,  3.19it/s]
#
#
#   3%|▎         | 41/1403 [00:11<07:09,  3.17it/s]
#
#
#   3%|▎         | 42/1403 [00:11<06:54,  3.28it/s]
#
#
#   3%|▎         | 43/1403 [00:12<06:39,  3.41it/s]
#
#
#   3%|▎         | 44/1403 [00:12<06:19,  3.58it/s]
#
#
#   3%|▎         | 45/1403 [00:12<06:21,  3.56it/s]
#
#
#   3%|▎         | 46/1403 [00:13<06:42,  3.37it/s]
#
#
#   3%|▎         | 47/1403 [00:13<06:52,  3.29it/s]
#
#
#   3%|▎         | 48/1403 [00:13<06:36,  3.42it/s]
#
#
#   3%|▎         | 49/1403 [00:14<07:05,  3.18it/s]
#
#
#   4%|▎         | 50/1403 [00:14<07:31,  3.00it/s]
#
#
#   4%|▎         | 51/1403 [00:14<07:22,  3.05it/s]
#
#
#   4%|▎         | 52/1403 [00:14<06:53,  3.26it/s]
#
#
#   4%|▍         | 53/1403 [00:15<07:08,  3.15it/s]
#
#
#   4%|▍         | 54/1403 [00:15<06:56,  3.24it/s]
#
#
#   4%|▍         | 55/1403 [00:15<07:03,  3.18it/s]
#
#
#   4%|▍         | 56/1403 [00:16<08:39,  2.59it/s]
#
#
#   4%|▍         | 57/1403 [00:16<09:04,  2.47it/s]
#
#
#   4%|▍         | 58/1403 [00:17<08:34,  2.62it/s]
#
#
#   4%|▍         | 60/1403 [00:17<07:10,  3.12it/s]
#
#
#   4%|▍         | 61/1403 [00:17<07:17,  3.07it/s]
#
#
#   4%|▍         | 62/1403 [00:18<07:37,  2.93it/s]
#
#
#   4%|▍         | 63/1403 [00:18<07:09,  3.12it/s]
#
#
#   5%|▍         | 64/1403 [00:19<08:41,  2.57it/s]
#
#
#   5%|▍         | 65/1403 [00:19<07:51,  2.84it/s]
#
#
#   5%|▍         | 66/1403 [00:19<07:31,  2.96it/s]
#
#
#   5%|▍         | 67/1403 [00:20<07:23,  3.01it/s]
#
#
#   5%|▍         | 68/1403 [00:20<07:09,  3.11it/s]
#
#
#   5%|▍         | 69/1403 [00:20<08:00,  2.77it/s]
#
#
#   5%|▍         | 70/1403 [00:21<07:44,  2.87it/s]
#
#
#   5%|▌         | 71/1403 [00:21<07:13,  3.07it/s]
#
#
#   5%|▌         | 72/1403 [00:21<07:27,  2.97it/s]
#
#
#   5%|▌         | 73/1403 [00:22<07:23,  3.00it/s]
#
#
#   5%|▌         | 74/1403 [00:22<06:53,  3.22it/s]
#
#
#   5%|▌         | 75/1403 [00:22<06:41,  3.31it/s]
#
#
#   5%|▌         | 76/1403 [00:22<06:49,  3.24it/s]
#
#
#   5%|▌         | 77/1403 [00:23<07:52,  2.80it/s]
#
#
#   6%|▌         | 78/1403 [00:24<12:11,  1.81it/s]
#
#
#   6%|▌         | 79/1403 [00:25<14:59,  1.47it/s]
#
#
#   6%|▌         | 80/1403 [00:26<17:34,  1.25it/s]
#
#
#   6%|▌         | 81/1403 [00:27<19:39,  1.12it/s]
#
#
#   6%|▌         | 82/1403 [00:28<22:08,  1.01s/it]
#
#
#   6%|▌         | 83/1403 [00:29<21:46,  1.01it/s]
#
#
#   6%|▌         | 84/1403 [00:30<21:39,  1.02it/s]
#
#
#   6%|▌         | 85/1403 [00:31<21:23,  1.03it/s]
#
#
#   6%|▌         | 86/1403 [00:33<23:24,  1.07s/it]
#
#
#   6%|▌         | 87/1403 [00:34<23:48,  1.09s/it]
#
#
#   6%|▋         | 88/1403 [00:35<23:49,  1.09s/it]
#
#
#   6%|▋         | 89/1403 [00:36<23:59,  1.10s/it]
#
#
#   6%|▋         | 90/1403 [00:37<24:58,  1.14s/it]
#
#
#   6%|▋         | 91/1403 [00:38<23:50,  1.09s/it]
#
#
#   7%|▋         | 92/1403 [00:39<23:29,  1.07s/it]
#
#
#   7%|▋         | 93/1403 [00:40<22:18,  1.02s/it]
#
#
#   7%|▋         | 94/1403 [00:41<22:30,  1.03s/it]
#
#
#   7%|▋         | 95/1403 [00:42<22:44,  1.04s/it]
#
#
#   7%|▋         | 96/1403 [00:43<21:39,  1.01it/s]
#
#
#   7%|▋         | 97/1403 [00:44<20:46,  1.05it/s]
#
#
#   7%|▋         | 98/1403 [00:45<21:20,  1.02it/s]
#
#
#   7%|▋         | 99/1403 [00:46<19:57,  1.09it/s]
#
#
#   7%|▋         | 100/1403 [00:47<20:40,  1.05it/s]
#
#
#   7%|▋         | 101/1403 [00:48<21:51,  1.01s/it]
#
#
#   7%|▋         | 102/1403 [00:49<21:25,  1.01it/s]
#
#
#   7%|▋         | 103/1403 [00:50<21:57,  1.01s/it]
#
#
#   7%|▋         | 104/1403 [00:51<22:32,  1.04s/it]
#
#
#   7%|▋         | 105/1403 [00:52<22:34,  1.04s/it]
#
#
#   8%|▊         | 106/1403 [00:53<22:18,  1.03s/it]
#
#
#   8%|▊         | 107/1403 [00:54<21:25,  1.01it/s]
#
#
#   8%|▊         | 108/1403 [00:55<22:04,  1.02s/it]
#
#
#   8%|▊         | 109/1403 [00:56<22:37,  1.05s/it]
#
#
#   8%|▊         | 110/1403 [00:57<21:57,  1.02s/it]
#
#
#   8%|▊         | 111/1403 [00:58<22:58,  1.07s/it]
#
#
#   8%|▊         | 112/1403 [00:59<22:00,  1.02s/it]
#
#
#   8%|▊         | 113/1403 [01:00<22:44,  1.06s/it]
#
#
#   8%|▊         | 114/1403 [01:01<21:19,  1.01it/s]
#
#
#   8%|▊         | 115/1403 [01:02<22:54,  1.07s/it]
#
#
#   8%|▊         | 116/1403 [01:03<22:46,  1.06s/it]
#
#
#   8%|▊         | 117/1403 [01:04<22:05,  1.03s/it]
#
#
#   8%|▊         | 118/1403 [01:05<21:43,  1.01s/it]
#
#
#   8%|▊         | 119/1403 [01:06<20:57,  1.02it/s]
#
#
#   9%|▊         | 120/1403 [01:07<20:57,  1.02it/s]
#
#
#   9%|▊         | 121/1403 [01:08<21:06,  1.01it/s]
#
#
#   9%|▊         | 122/1403 [01:09<21:25,  1.00s/it]
#
#
#   9%|▉         | 123/1403 [01:10<20:07,  1.06it/s]
#
#
#   9%|▉         | 124/1403 [01:11<21:03,  1.01it/s]
#
#
#   9%|▉         | 125/1403 [01:12<21:26,  1.01s/it]
#
#
#   9%|▉         | 126/1403 [01:13<22:49,  1.07s/it]
#
#
#   9%|▉         | 127/1403 [01:15<22:37,  1.06s/it]
#
#
#   9%|▉         | 128/1403 [01:16<22:34,  1.06s/it]
#
#
#   9%|▉         | 129/1403 [01:17<21:40,  1.02s/it]
#
#
#   9%|▉         | 130/1403 [01:18<22:15,  1.05s/it]
#
#
#   9%|▉         | 131/1403 [01:19<22:11,  1.05s/it]
#
#
#   9%|▉         | 132/1403 [01:19<20:13,  1.05it/s]
#
#
#   9%|▉         | 133/1403 [01:21<21:13,  1.00s/it]
#
#
#  10%|▉         | 134/1403 [01:22<21:39,  1.02s/it]
#
#
#  10%|▉         | 135/1403 [01:23<21:12,  1.00s/it]
#
#
#  10%|▉         | 136/1403 [01:23<20:25,  1.03it/s]
#
#
#  10%|▉         | 137/1403 [01:24<19:43,  1.07it/s]
#
#
#  10%|▉         | 138/1403 [01:25<19:38,  1.07it/s]
#
#
#  10%|▉         | 139/1403 [01:26<21:02,  1.00it/s]
#
#
#  10%|▉         | 140/1403 [01:27<21:14,  1.01s/it]
#
#
#  10%|█         | 141/1403 [01:29<21:48,  1.04s/it]
#
#
#  10%|█         | 142/1403 [01:29<21:16,  1.01s/it]
#
#
#  10%|█         | 143/1403 [01:31<21:56,  1.04s/it]
#
#
#  10%|█         | 144/1403 [01:31<20:56,  1.00it/s]
#
#
#  10%|█         | 145/1403 [01:32<20:54,  1.00it/s]
#
#
#  10%|█         | 146/1403 [01:33<20:19,  1.03it/s]
#
#
#  10%|█         | 147/1403 [01:34<19:37,  1.07it/s]
#
#
#  11%|█         | 148/1403 [01:35<19:12,  1.09it/s]
#
#
#  11%|█         | 149/1403 [01:36<20:34,  1.02it/s]
#
#
#  11%|█         | 150/1403 [01:37<20:58,  1.00s/it]
#
#
#  11%|█         | 151/1403 [01:38<19:12,  1.09it/s]
#
#
#  11%|█         | 152/1403 [01:39<18:17,  1.14it/s]
#
#
#  11%|█         | 153/1403 [01:40<18:07,  1.15it/s]
#
#
#  11%|█         | 154/1403 [01:40<17:38,  1.18it/s]
#
#
#  11%|█         | 155/1403 [01:41<17:14,  1.21it/s]
#
#
#  11%|█         | 156/1403 [01:42<17:05,  1.22it/s]
#
#
#  11%|█         | 157/1403 [01:43<18:11,  1.14it/s]
#
#
#  11%|█▏        | 158/1403 [01:44<17:28,  1.19it/s]
#
#
#  11%|█▏        | 159/1403 [01:45<17:51,  1.16it/s]
#
#
#  11%|█▏        | 160/1403 [01:46<18:26,  1.12it/s]
#
#
#  11%|█▏        | 161/1403 [01:47<18:47,  1.10it/s]
#
#
#  12%|█▏        | 162/1403 [01:48<19:40,  1.05it/s]
#
#
#  12%|█▏        | 163/1403 [01:49<19:47,  1.04it/s]
#
#
#  12%|█▏        | 164/1403 [01:50<20:39,  1.00s/it]
#
#
#  12%|█▏        | 165/1403 [01:51<19:59,  1.03it/s]
#
#
#  12%|█▏        | 166/1403 [01:51<18:49,  1.09it/s]
#
#
#  12%|█▏        | 167/1403 [01:52<17:59,  1.15it/s]
#
#
#  12%|█▏        | 168/1403 [01:53<18:20,  1.12it/s]
#
#
#  12%|█▏        | 169/1403 [01:54<18:46,  1.10it/s]
#
#
#  12%|█▏        | 170/1403 [01:55<19:12,  1.07it/s]
#
#
#  12%|█▏        | 171/1403 [01:56<20:39,  1.01s/it]
#
#
#  12%|█▏        | 172/1403 [01:57<20:19,  1.01it/s]
#
#
#  12%|█▏        | 173/1403 [01:58<18:57,  1.08it/s]
#
#
#  12%|█▏        | 174/1403 [01:59<18:24,  1.11it/s]
#
#
#  12%|█▏        | 175/1403 [02:00<19:06,  1.07it/s]
#
#
#  13%|█▎        | 176/1403 [02:01<20:33,  1.01s/it]
#
#
#  13%|█▎        | 177/1403 [02:02<20:34,  1.01s/it]
#
#
#  13%|█▎        | 178/1403 [02:03<19:42,  1.04it/s]
#
#
#  13%|█▎        | 179/1403 [02:04<18:29,  1.10it/s]
#
#
#  13%|█▎        | 180/1403 [02:05<19:19,  1.05it/s]
#
#
#  13%|█▎        | 181/1403 [02:06<18:35,  1.10it/s]
#
#
#  13%|█▎        | 182/1403 [02:07<20:26,  1.00s/it]
#
#
#  13%|█▎        | 183/1403 [02:08<20:45,  1.02s/it]
#
#
#  13%|█▎        | 184/1403 [02:09<20:26,  1.01s/it]
#
#
#  13%|█▎        | 185/1403 [02:10<18:56,  1.07it/s]
#
#
#  13%|█▎        | 186/1403 [02:10<19:01,  1.07it/s]
#
#
#  13%|█▎        | 187/1403 [02:11<17:55,  1.13it/s]
#
#
#  13%|█▎        | 188/1403 [02:12<17:02,  1.19it/s]
#
#
#  13%|█▎        | 189/1403 [02:13<18:58,  1.07it/s]
#
#
#  14%|█▎        | 190/1403 [02:14<19:21,  1.04it/s]
#
#
#  14%|█▎        | 191/1403 [02:15<20:27,  1.01s/it]
#
#
#  14%|█▎        | 192/1403 [02:16<19:12,  1.05it/s]
#
#
#  14%|█▍        | 193/1403 [02:17<18:48,  1.07it/s]
#
#
#  14%|█▍        | 194/1403 [02:18<19:06,  1.05it/s]
#
#
#  14%|█▍        | 195/1403 [02:19<18:53,  1.07it/s]
#
#
#  14%|█▍        | 196/1403 [02:20<19:04,  1.05it/s]
#
#
#  14%|█▍        | 197/1403 [02:21<17:28,  1.15it/s]
#
#
#  14%|█▍        | 198/1403 [02:21<17:31,  1.15it/s]
#
#
#  14%|█▍        | 199/1403 [02:23<19:32,  1.03it/s]
#
#
#  14%|█▍        | 200/1403 [02:24<20:18,  1.01s/it]
#
#
#  14%|█▍        | 201/1403 [02:25<20:16,  1.01s/it]
#
#
#  14%|█▍        | 202/1403 [02:26<19:54,  1.01it/s]
#
#
#  14%|█▍        | 203/1403 [02:26<18:36,  1.07it/s]
#
#
#  15%|█▍        | 204/1403 [02:27<18:37,  1.07it/s]
#
#
#  15%|█▍        | 205/1403 [02:28<18:06,  1.10it/s]
#
#
#  15%|█▍        | 206/1403 [02:29<17:54,  1.11it/s]
#
#
#  15%|█▍        | 207/1403 [02:30<19:00,  1.05it/s]
#
#
#  15%|█▍        | 208/1403 [02:31<18:26,  1.08it/s]
#
#
#  15%|█▍        | 209/1403 [02:32<18:05,  1.10it/s]
#
#
#  15%|█▍        | 210/1403 [02:33<18:45,  1.06it/s]
#
#
#  15%|█▌        | 211/1403 [02:34<18:06,  1.10it/s]
#
#
#  15%|█▌        | 212/1403 [02:35<17:17,  1.15it/s]
#
#
#  15%|█▌        | 213/1403 [02:35<16:18,  1.22it/s]
#
#
#  15%|█▌        | 214/1403 [02:36<17:19,  1.14it/s]
#
#
#  15%|█▌        | 215/1403 [02:37<18:28,  1.07it/s]
#
#
#  15%|█▌        | 216/1403 [02:38<18:10,  1.09it/s]
#
#
#  15%|█▌        | 217/1403 [02:39<19:09,  1.03it/s]
#
#
#  16%|█▌        | 218/1403 [02:40<18:11,  1.09it/s]
#
#
#  16%|█▌        | 219/1403 [02:41<16:47,  1.17it/s]
#
#
#  16%|█▌        | 220/1403 [02:42<17:53,  1.10it/s]
#
#
#  16%|█▌        | 221/1403 [02:43<17:40,  1.11it/s]
#
#
#  16%|█▌        | 222/1403 [02:43<16:38,  1.18it/s]
#
#
#  16%|█▌        | 223/1403 [02:44<16:07,  1.22it/s]
#
#
#  16%|█▌        | 224/1403 [02:45<18:27,  1.06it/s]
#
#
#  16%|█▌        | 225/1403 [02:46<17:31,  1.12it/s]
#
#
#  16%|█▌        | 226/1403 [02:47<18:57,  1.03it/s]
#
#
#  16%|█▌        | 227/1403 [02:48<19:47,  1.01s/it]
#
#
#  16%|█▋        | 228/1403 [02:49<19:02,  1.03it/s]
#
#
#  16%|█▋        | 229/1403 [02:50<18:36,  1.05it/s]
#
#
#  16%|█▋        | 230/1403 [02:51<17:22,  1.12it/s]
#
#
#  16%|█▋        | 231/1403 [02:52<17:13,  1.13it/s]
#
#
#  17%|█▋        | 232/1403 [02:53<16:08,  1.21it/s]
#
#
#  17%|█▋        | 233/1403 [02:54<17:05,  1.14it/s]
#
#
#  17%|█▋        | 234/1403 [02:55<17:27,  1.12it/s]
#
#
#  17%|█▋        | 235/1403 [02:55<16:25,  1.19it/s]
#
#
#  17%|█▋        | 236/1403 [02:56<18:10,  1.07it/s]
#
#
#  17%|█▋        | 237/1403 [02:57<18:11,  1.07it/s]
#
#
#  17%|█▋        | 238/1403 [02:58<18:12,  1.07it/s]
#
#
#  17%|█▋        | 239/1403 [02:59<19:01,  1.02it/s]
#
#
#  17%|█▋        | 240/1403 [03:01<20:18,  1.05s/it]
#
#
#  17%|█▋        | 241/1403 [03:01<19:09,  1.01it/s]
#
#
#  17%|█▋        | 242/1403 [03:03<24:56,  1.29s/it]
#
#
#  17%|█▋        | 243/1403 [03:04<22:07,  1.14s/it]
#
#
#  17%|█▋        | 244/1403 [03:05<20:32,  1.06s/it]
#
#
#  17%|█▋        | 245/1403 [03:06<19:48,  1.03s/it]
#
#
#  18%|█▊        | 246/1403 [03:07<19:12,  1.00it/s]
#
#
#  18%|█▊        | 247/1403 [03:08<19:35,  1.02s/it]
#
#
#  18%|█▊        | 248/1403 [03:09<18:34,  1.04it/s]
#
#
#  18%|█▊        | 249/1403 [03:10<17:22,  1.11it/s]
#
#
#  18%|█▊        | 250/1403 [03:11<17:36,  1.09it/s]
#
#
#  18%|█▊        | 251/1403 [03:12<18:44,  1.02it/s]
#
#
#  18%|█▊        | 252/1403 [03:13<18:38,  1.03it/s]
#
#
#  18%|█▊        | 253/1403 [03:14<21:21,  1.11s/it]
#
#
#  18%|█▊        | 254/1403 [03:15<20:23,  1.06s/it]
#
#
#  18%|█▊        | 255/1403 [03:16<20:53,  1.09s/it]
#
#
#  18%|█▊        | 256/1403 [03:17<20:03,  1.05s/it]
#
#
#  18%|█▊        | 257/1403 [03:18<20:05,  1.05s/it]
#
#
#  18%|█▊        | 258/1403 [03:19<19:33,  1.03s/it]
#
#
#  18%|█▊        | 259/1403 [03:20<18:28,  1.03it/s]
#
#
#  19%|█▊        | 260/1403 [03:21<18:46,  1.01it/s]
#
#
#  19%|█▊        | 261/1403 [03:22<18:16,  1.04it/s]
#
#
#  19%|█▊        | 262/1403 [03:23<18:10,  1.05it/s]
#
#
#  19%|█▊        | 263/1403 [03:24<19:01,  1.00s/it]
#
#
#  19%|█▉        | 264/1403 [03:25<19:05,  1.01s/it]
#
#
#  19%|█▉        | 265/1403 [03:26<19:46,  1.04s/it]
#
#
#  19%|█▉        | 266/1403 [03:27<19:04,  1.01s/it]
#
#
#  19%|█▉        | 267/1403 [03:28<18:32,  1.02it/s]
#
#
#  19%|█▉        | 268/1403 [03:29<19:03,  1.01s/it]
#
#
#  19%|█▉        | 269/1403 [03:30<19:32,  1.03s/it]
#
#
#  19%|█▉        | 270/1403 [03:31<20:02,  1.06s/it]
#
#
#  19%|█▉        | 271/1403 [03:32<20:30,  1.09s/it]
#
#
#  19%|█▉        | 272/1403 [03:33<19:16,  1.02s/it]
#
#
#  19%|█▉        | 273/1403 [03:34<18:30,  1.02it/s]
#
#
#  20%|█▉        | 274/1403 [03:35<18:08,  1.04it/s]
#
#
#  20%|█▉        | 275/1403 [03:36<17:53,  1.05it/s]
#
#
#  20%|█▉        | 276/1403 [03:37<17:40,  1.06it/s]
#
#
#  20%|█▉        | 277/1403 [03:38<18:49,  1.00s/it]
#
#
#  20%|█▉        | 278/1403 [03:39<19:30,  1.04s/it]
#
#
#  20%|█▉        | 279/1403 [03:40<20:41,  1.10s/it]
#
#
#  20%|█▉        | 280/1403 [03:41<19:46,  1.06s/it]
#
#
#  20%|██        | 281/1403 [03:42<19:47,  1.06s/it]
#
#
#  20%|██        | 282/1403 [03:44<19:53,  1.06s/it]
#
#
#  20%|██        | 283/1403 [03:44<18:41,  1.00s/it]
#
#
#  20%|██        | 284/1403 [03:45<18:58,  1.02s/it]
#
#
#  20%|██        | 285/1403 [03:46<18:44,  1.01s/it]
#
#
#  20%|██        | 286/1403 [03:47<16:56,  1.10it/s]
#
#
#  20%|██        | 287/1403 [03:48<16:38,  1.12it/s]
#
#
#  21%|██        | 288/1403 [03:49<16:55,  1.10it/s]
#
#
#  21%|██        | 289/1403 [03:50<16:57,  1.09it/s]
#
#
#  21%|██        | 290/1403 [03:51<16:49,  1.10it/s]
#
#
#  21%|██        | 291/1403 [03:52<17:55,  1.03it/s]
#
#
#  21%|██        | 292/1403 [03:53<17:35,  1.05it/s]
#
#
#  21%|██        | 293/1403 [03:54<17:12,  1.08it/s]
#
#
#  21%|██        | 294/1403 [03:55<18:09,  1.02it/s]
#
#
#  21%|██        | 295/1403 [03:56<17:23,  1.06it/s]
#
#
#  21%|██        | 296/1403 [03:57<17:45,  1.04it/s]
#
#
#  21%|██        | 297/1403 [03:58<17:44,  1.04it/s]
#
#
#  21%|██        | 298/1403 [03:59<18:29,  1.00s/it]
#
#
#  21%|██▏       | 299/1403 [03:59<17:17,  1.06it/s]
#
#
#  21%|██▏       | 300/1403 [04:00<17:25,  1.06it/s]
#
#
#  21%|██▏       | 301/1403 [04:01<16:53,  1.09it/s]
#
#
#  22%|██▏       | 302/1403 [04:02<18:04,  1.01it/s]
#
#
#  22%|██▏       | 303/1403 [04:03<18:23,  1.00s/it]
#
#
#  22%|██▏       | 304/1403 [04:04<18:29,  1.01s/it]
#
#
#  22%|██▏       | 305/1403 [04:06<18:46,  1.03s/it]
#
#
#  22%|██▏       | 306/1403 [04:07<18:35,  1.02s/it]
#
#
#  22%|██▏       | 307/1403 [04:07<17:27,  1.05it/s]
#
#
#  22%|██▏       | 308/1403 [04:08<17:42,  1.03it/s]
#
#
#  22%|██▏       | 309/1403 [04:09<17:19,  1.05it/s]
#
#
#  22%|██▏       | 310/1403 [04:10<17:57,  1.01it/s]
#
#
#  22%|██▏       | 311/1403 [04:11<17:09,  1.06it/s]
#
#
#  22%|██▏       | 312/1403 [04:12<15:25,  1.18it/s]
#
#
#  22%|██▏       | 313/1403 [04:13<15:40,  1.16it/s]
#
#
#  22%|██▏       | 314/1403 [04:14<16:36,  1.09it/s]
#
#
#  22%|██▏       | 315/1403 [04:15<17:51,  1.02it/s]
#
#
#  23%|██▎       | 316/1403 [04:16<17:13,  1.05it/s]
#
#
#  23%|██▎       | 317/1403 [04:17<16:56,  1.07it/s]
#
#
#  23%|██▎       | 318/1403 [04:18<16:56,  1.07it/s]
#
#
#  23%|██▎       | 319/1403 [04:18<16:44,  1.08it/s]
#
#
#  23%|██▎       | 320/1403 [04:19<16:03,  1.12it/s]
#
#
#  23%|██▎       | 321/1403 [04:20<17:42,  1.02it/s]
#
#
#  23%|██▎       | 322/1403 [04:21<17:34,  1.03it/s]
#
#
#  23%|██▎       | 323/1403 [04:22<17:54,  1.00it/s]
#
#
#  23%|██▎       | 324/1403 [04:24<18:08,  1.01s/it]
#
#
#  23%|██▎       | 325/1403 [04:24<17:26,  1.03it/s]
#
#
#  23%|██▎       | 326/1403 [04:25<17:41,  1.01it/s]
#
#
#  23%|██▎       | 327/1403 [04:27<19:18,  1.08s/it]
#
#
#  23%|██▎       | 328/1403 [04:28<19:23,  1.08s/it]
#
#
#  23%|██▎       | 329/1403 [04:29<17:36,  1.02it/s]
#
#
#  24%|██▎       | 330/1403 [04:29<16:59,  1.05it/s]
#
#
#  24%|██▎       | 331/1403 [04:30<15:47,  1.13it/s]
#
#
#  24%|██▎       | 332/1403 [04:31<14:55,  1.20it/s]
#
#
#  24%|██▎       | 333/1403 [04:32<16:17,  1.09it/s]
#
#
#  24%|██▍       | 334/1403 [04:33<16:08,  1.10it/s]
#
#
#  24%|██▍       | 335/1403 [04:34<16:40,  1.07it/s]
#
#
#  24%|██▍       | 336/1403 [04:35<15:44,  1.13it/s]
#
#
#  24%|██▍       | 337/1403 [04:36<17:35,  1.01it/s]
#
#
#  24%|██▍       | 338/1403 [04:37<16:51,  1.05it/s]
#
#
#  24%|██▍       | 339/1403 [04:38<17:10,  1.03it/s]
#
#
#  24%|██▍       | 340/1403 [04:39<16:21,  1.08it/s]
#
#
#  24%|██▍       | 341/1403 [04:39<16:17,  1.09it/s]
#
#
#  24%|██▍       | 342/1403 [04:41<17:28,  1.01it/s]
#
#
#  24%|██▍       | 343/1403 [04:42<17:26,  1.01it/s]
#
#
#  25%|██▍       | 344/1403 [04:43<17:12,  1.03it/s]
#
#
#  25%|██▍       | 345/1403 [04:43<16:05,  1.10it/s]
#
#
#  25%|██▍       | 346/1403 [04:44<16:43,  1.05it/s]
#
#
#  25%|██▍       | 347/1403 [04:45<16:07,  1.09it/s]
#
#
#  25%|██▍       | 348/1403 [04:46<14:50,  1.18it/s]
#
#
#  25%|██▍       | 349/1403 [04:47<15:02,  1.17it/s]
#
#
#  25%|██▍       | 350/1403 [04:48<15:06,  1.16it/s]
#
#
#  25%|██▌       | 351/1403 [04:49<15:54,  1.10it/s]
#
#
#  25%|██▌       | 352/1403 [04:50<16:25,  1.07it/s]
#
#
#  25%|██▌       | 353/1403 [04:51<17:36,  1.01s/it]
#
#
#  25%|██▌       | 354/1403 [04:52<16:33,  1.06it/s]
#
#
#  25%|██▌       | 355/1403 [04:52<15:57,  1.09it/s]
#
#
#  25%|██▌       | 356/1403 [04:54<17:35,  1.01s/it]
#
#
#  25%|██▌       | 357/1403 [04:55<16:43,  1.04it/s]
#
#
#  26%|██▌       | 358/1403 [04:55<15:28,  1.13it/s]
#
#
#  26%|██▌       | 359/1403 [04:56<15:09,  1.15it/s]
#
#
#  26%|██▌       | 360/1403 [04:57<16:25,  1.06it/s]
#
#
#  26%|██▌       | 361/1403 [04:58<15:30,  1.12it/s]
#
#
#  26%|██▌       | 362/1403 [04:59<15:02,  1.15it/s]
#
#
#  26%|██▌       | 363/1403 [05:00<17:12,  1.01it/s]
#
#
#  26%|██▌       | 364/1403 [05:01<16:36,  1.04it/s]
#
#
#  26%|██▌       | 365/1403 [05:02<16:03,  1.08it/s]
#
#
#  26%|██▌       | 366/1403 [05:03<15:53,  1.09it/s]
#
#
#  26%|██▌       | 367/1403 [05:04<15:08,  1.14it/s]
#
#
#  26%|██▌       | 368/1403 [05:05<15:48,  1.09it/s]
#
#
#  26%|██▋       | 369/1403 [05:06<17:26,  1.01s/it]
#
#
#  26%|██▋       | 370/1403 [05:07<17:16,  1.00s/it]
#
#
#  26%|██▋       | 371/1403 [05:08<16:49,  1.02it/s]
#
#
#  27%|██▋       | 372/1403 [05:09<17:12,  1.00s/it]
#
#
#  27%|██▋       | 373/1403 [05:10<17:10,  1.00s/it]
#
#
#  27%|██▋       | 374/1403 [05:11<18:46,  1.09s/it]
#
#
#  27%|██▋       | 375/1403 [05:12<17:06,  1.00it/s]
#
#
#  27%|██▋       | 376/1403 [05:13<17:22,  1.01s/it]
#
#
#  27%|██▋       | 377/1403 [05:14<17:34,  1.03s/it]
#
#
#  27%|██▋       | 378/1403 [05:15<18:36,  1.09s/it]
#
#
#  27%|██▋       | 379/1403 [05:16<18:29,  1.08s/it]
#
#
#  27%|██▋       | 380/1403 [05:17<18:52,  1.11s/it]
#
#
#  27%|██▋       | 381/1403 [05:18<18:23,  1.08s/it]
#
#
#  27%|██▋       | 382/1403 [05:19<18:34,  1.09s/it]
#
#
#  27%|██▋       | 383/1403 [05:21<18:20,  1.08s/it]
#
#
#  27%|██▋       | 384/1403 [05:21<17:33,  1.03s/it]
#
#
#  27%|██▋       | 385/1403 [05:23<18:02,  1.06s/it]
#
#
#  28%|██▊       | 386/1403 [05:24<17:49,  1.05s/it]
#
#
#  28%|██▊       | 387/1403 [05:25<19:18,  1.14s/it]
#
#
#  28%|██▊       | 388/1403 [05:26<19:39,  1.16s/it]
#
#
#  28%|██▊       | 389/1403 [05:27<18:50,  1.12s/it]
#
#
#  28%|██▊       | 390/1403 [05:28<18:23,  1.09s/it]
#
#
#  28%|██▊       | 391/1403 [05:29<18:19,  1.09s/it]
#
#
#  28%|██▊       | 392/1403 [05:30<17:55,  1.06s/it]
#
#
#  28%|██▊       | 393/1403 [05:31<17:13,  1.02s/it]
#
#
#  28%|██▊       | 394/1403 [05:33<21:55,  1.30s/it]
#
#
#  28%|██▊       | 395/1403 [05:34<20:40,  1.23s/it]
#
#
#  28%|██▊       | 396/1403 [05:35<19:56,  1.19s/it]
#
#
#  28%|██▊       | 397/1403 [05:36<18:15,  1.09s/it]
#
#
#  28%|██▊       | 398/1403 [05:37<17:37,  1.05s/it]
#
#
#  28%|██▊       | 399/1403 [05:38<16:41,  1.00it/s]
#
#
#  29%|██▊       | 400/1403 [05:39<17:10,  1.03s/it]
#
#
#  29%|██▊       | 401/1403 [05:40<17:01,  1.02s/it]
#
#
#  29%|██▊       | 402/1403 [05:41<16:38,  1.00it/s]
#
#
#  29%|██▊       | 403/1403 [05:42<16:23,  1.02it/s]
#
#
#  29%|██▉       | 404/1403 [05:43<15:47,  1.05it/s]
#
#
#  29%|██▉       | 405/1403 [05:44<16:34,  1.00it/s]
#
#
#  29%|██▉       | 406/1403 [05:45<17:31,  1.06s/it]
#
#
#  29%|██▉       | 407/1403 [05:46<16:23,  1.01it/s]
#
#
#  29%|██▉       | 408/1403 [05:47<16:24,  1.01it/s]
#
#
#  29%|██▉       | 409/1403 [05:48<16:49,  1.02s/it]
#
#
#  29%|██▉       | 410/1403 [05:49<18:09,  1.10s/it]
#
#
#  29%|██▉       | 411/1403 [05:51<19:48,  1.20s/it]
#
#
#  29%|██▉       | 412/1403 [05:52<19:58,  1.21s/it]
#
#
#  29%|██▉       | 413/1403 [05:53<18:44,  1.14s/it]
#
#
#  30%|██▉       | 414/1403 [05:54<17:47,  1.08s/it]
#
#
#  30%|██▉       | 415/1403 [05:55<18:35,  1.13s/it]
#
#
#  30%|██▉       | 416/1403 [05:56<17:12,  1.05s/it]
#
#
#  30%|██▉       | 417/1403 [05:57<17:29,  1.06s/it]
#
#
#  30%|██▉       | 418/1403 [05:58<16:48,  1.02s/it]
#
#
#  30%|██▉       | 419/1403 [05:59<16:38,  1.01s/it]
#
#
#  30%|██▉       | 420/1403 [06:00<15:43,  1.04it/s]
#
#
#  30%|███       | 421/1403 [06:01<16:06,  1.02it/s]
#
#
#  30%|███       | 422/1403 [06:02<15:20,  1.07it/s]
#
#
#  30%|███       | 423/1403 [06:03<15:01,  1.09it/s]
#
#
#  30%|███       | 424/1403 [06:03<14:26,  1.13it/s]
#
#
#  30%|███       | 425/1403 [06:04<14:39,  1.11it/s]
#
#
#  30%|███       | 426/1403 [06:05<15:07,  1.08it/s]
#
#
#  30%|███       | 427/1403 [06:06<14:26,  1.13it/s]
#
#
#  31%|███       | 428/1403 [06:07<16:03,  1.01it/s]
#
#
#  31%|███       | 429/1403 [06:09<17:25,  1.07s/it]
#
#
#  31%|███       | 430/1403 [06:10<16:53,  1.04s/it]
#
#
#  31%|███       | 431/1403 [06:11<16:16,  1.00s/it]
#
#
#  31%|███       | 432/1403 [06:11<15:14,  1.06it/s]
#
#
#  31%|███       | 433/1403 [06:12<15:09,  1.07it/s]
#
#
#  31%|███       | 434/1403 [06:13<15:39,  1.03it/s]
#
#
#  31%|███       | 435/1403 [06:14<15:28,  1.04it/s]
#
#
#  31%|███       | 436/1403 [06:15<14:32,  1.11it/s]
#
#
#  31%|███       | 437/1403 [06:16<14:34,  1.10it/s]
#
#
#  31%|███       | 438/1403 [06:17<13:51,  1.16it/s]
#
#
#  31%|███▏      | 439/1403 [06:18<13:58,  1.15it/s]
#
#
#  31%|███▏      | 440/1403 [06:18<12:00,  1.34it/s]
#
#
#  31%|███▏      | 441/1403 [06:19<12:54,  1.24it/s]
#
#
#  32%|███▏      | 442/1403 [06:20<14:23,  1.11it/s]
#
#
#  32%|███▏      | 443/1403 [06:21<14:36,  1.10it/s]
#
#
#  32%|███▏      | 444/1403 [06:22<14:58,  1.07it/s]
#
#
#  32%|███▏      | 445/1403 [06:23<15:06,  1.06it/s]
#
#
#  32%|███▏      | 446/1403 [06:24<14:53,  1.07it/s]
#
#
#  32%|███▏      | 447/1403 [06:25<14:46,  1.08it/s]
#
#
#  32%|███▏      | 448/1403 [06:26<14:53,  1.07it/s]
#
#
#  32%|███▏      | 449/1403 [06:27<14:50,  1.07it/s]
#
#
#  32%|███▏      | 450/1403 [06:28<15:41,  1.01it/s]
#
#
#  32%|███▏      | 451/1403 [06:29<15:51,  1.00it/s]
#
#
#  32%|███▏      | 452/1403 [06:30<17:31,  1.11s/it]
#
#
#  32%|███▏      | 453/1403 [06:31<17:44,  1.12s/it]
#
#
#  32%|███▏      | 454/1403 [06:32<17:14,  1.09s/it]
#
#
#  32%|███▏      | 455/1403 [06:33<16:31,  1.05s/it]
#
#
#  33%|███▎      | 456/1403 [06:34<16:37,  1.05s/it]
#
#
#  33%|███▎      | 457/1403 [06:35<15:50,  1.00s/it]
#
#
#  33%|███▎      | 458/1403 [06:36<15:09,  1.04it/s]
#
#
#  33%|███▎      | 459/1403 [06:37<15:02,  1.05it/s]
#
#
#  33%|███▎      | 460/1403 [06:38<16:19,  1.04s/it]
#
#
#  33%|███▎      | 461/1403 [06:39<16:30,  1.05s/it]
#
#
#  33%|███▎      | 462/1403 [06:41<17:05,  1.09s/it]
#
#
#  33%|███▎      | 463/1403 [06:41<14:13,  1.10it/s]
#
#
#  33%|███▎      | 464/1403 [06:42<15:29,  1.01it/s]
#
#
#  33%|███▎      | 465/1403 [06:43<15:35,  1.00it/s]
#
#
#  33%|███▎      | 466/1403 [06:44<14:54,  1.05it/s]
#
#
#  33%|███▎      | 467/1403 [06:45<13:25,  1.16it/s]
#
#
#  33%|███▎      | 468/1403 [06:46<15:21,  1.01it/s]
#
#
#  33%|███▎      | 469/1403 [06:47<15:38,  1.00s/it]
#
#
#  33%|███▎      | 470/1403 [06:48<16:13,  1.04s/it]
#
#
#  34%|███▎      | 471/1403 [06:49<15:37,  1.01s/it]
#
#
#  34%|███▎      | 472/1403 [06:50<14:52,  1.04it/s]
#
#
#  34%|███▎      | 473/1403 [06:51<15:06,  1.03it/s]
#
#
#  34%|███▍      | 474/1403 [06:52<15:28,  1.00it/s]
#
#
#  34%|███▍      | 475/1403 [06:54<19:56,  1.29s/it]
#
#
#  34%|███▍      | 476/1403 [06:55<17:37,  1.14s/it]
#
#
#  34%|███▍      | 477/1403 [06:56<16:34,  1.07s/it]
#
#
#  34%|███▍      | 478/1403 [06:57<16:13,  1.05s/it]
#
#
#  34%|███▍      | 479/1403 [06:57<14:39,  1.05it/s]
#
#
#  34%|███▍      | 480/1403 [06:59<16:31,  1.07s/it]
#
#
#  34%|███▍      | 481/1403 [07:00<17:06,  1.11s/it]
#
#
#  34%|███▍      | 482/1403 [07:01<16:11,  1.05s/it]
#
#
#  34%|███▍      | 483/1403 [07:02<15:54,  1.04s/it]
#
#
#  34%|███▍      | 484/1403 [07:03<16:30,  1.08s/it]
#
#
#  35%|███▍      | 485/1403 [07:04<16:49,  1.10s/it]
#
#
#  35%|███▍      | 486/1403 [07:05<17:10,  1.12s/it]
#
#
#  35%|███▍      | 487/1403 [07:07<16:58,  1.11s/it]
#
#
#  35%|███▍      | 488/1403 [07:07<15:33,  1.02s/it]
#
#
#  35%|███▍      | 489/1403 [07:08<14:43,  1.03it/s]
#
#
#  35%|███▍      | 490/1403 [07:09<14:13,  1.07it/s]
#
#
#  35%|███▍      | 491/1403 [07:10<14:28,  1.05it/s]
#
#
#  35%|███▌      | 492/1403 [07:11<14:20,  1.06it/s]
#
#
#  35%|███▌      | 493/1403 [07:12<15:09,  1.00it/s]
#
#
#  35%|███▌      | 494/1403 [07:13<14:38,  1.03it/s]
#
#
#  35%|███▌      | 495/1403 [07:14<15:55,  1.05s/it]
#
#
#  35%|███▌      | 496/1403 [07:15<15:36,  1.03s/it]
#
#
#  35%|███▌      | 497/1403 [07:16<15:14,  1.01s/it]
#
#
#  35%|███▌      | 498/1403 [07:17<14:06,  1.07it/s]
#
#
#  36%|███▌      | 499/1403 [07:18<14:08,  1.07it/s]
#
#
#  36%|███▌      | 500/1403 [07:19<15:10,  1.01s/it]
#
#
#  36%|███▌      | 501/1403 [07:20<14:33,  1.03it/s]
#
#
#  36%|███▌      | 502/1403 [07:21<14:55,  1.01it/s]
#
#
#  36%|███▌      | 503/1403 [07:22<15:02,  1.00s/it]
#
#
#  36%|███▌      | 504/1403 [07:23<15:36,  1.04s/it]
#
#
#  36%|███▌      | 505/1403 [07:24<15:22,  1.03s/it]
#
#
#  36%|███▌      | 506/1403 [07:25<14:30,  1.03it/s]
#
#
#  36%|███▌      | 507/1403 [07:26<14:35,  1.02it/s]
#
#
#  36%|███▌      | 508/1403 [07:27<15:01,  1.01s/it]
#
#
#  36%|███▋      | 509/1403 [07:28<14:14,  1.05it/s]
#
#
#  36%|███▋      | 510/1403 [07:29<14:48,  1.01it/s]
#
#
#  36%|███▋      | 511/1403 [07:30<15:29,  1.04s/it]
#
#
#  36%|███▋      | 512/1403 [07:31<14:36,  1.02it/s]
#
#
#  37%|███▋      | 513/1403 [07:32<14:03,  1.06it/s]
#
#
#  37%|███▋      | 514/1403 [07:33<13:30,  1.10it/s]
#
#
#  37%|███▋      | 515/1403 [07:34<13:34,  1.09it/s]
#
#
#  37%|███▋      | 516/1403 [07:35<13:32,  1.09it/s]
#
#
#  37%|███▋      | 517/1403 [07:35<13:40,  1.08it/s]
#
#
#  37%|███▋      | 518/1403 [07:36<13:43,  1.07it/s]
#
#
#  37%|███▋      | 519/1403 [07:37<13:49,  1.07it/s]
#
#
#  37%|███▋      | 520/1403 [07:38<14:24,  1.02it/s]
#
#
#  37%|███▋      | 521/1403 [07:39<14:24,  1.02it/s]
#
#
#  37%|███▋      | 522/1403 [07:40<13:45,  1.07it/s]
#
#
#  37%|███▋      | 523/1403 [07:41<14:23,  1.02it/s]
#
#
#  37%|███▋      | 524/1403 [07:42<14:39,  1.00s/it]
#
#
#  37%|███▋      | 525/1403 [07:44<15:12,  1.04s/it]
#
#
#  37%|███▋      | 526/1403 [07:44<14:09,  1.03it/s]
#
#
#  38%|███▊      | 527/1403 [07:45<14:09,  1.03it/s]
#
#
#  38%|███▊      | 528/1403 [07:46<14:12,  1.03it/s]
#
#
#  38%|███▊      | 529/1403 [07:47<13:48,  1.05it/s]
#
#
#  38%|███▊      | 530/1403 [07:48<13:26,  1.08it/s]
#
#
#  38%|███▊      | 531/1403 [07:49<13:48,  1.05it/s]
#
#
#  38%|███▊      | 532/1403 [07:50<15:00,  1.03s/it]
#
#
#  38%|███▊      | 533/1403 [07:51<14:50,  1.02s/it]
#
#
#  38%|███▊      | 534/1403 [07:53<15:53,  1.10s/it]
#
#
#  38%|███▊      | 535/1403 [07:54<16:23,  1.13s/it]
#
#
#  38%|███▊      | 536/1403 [07:55<15:02,  1.04s/it]
#
#
#  38%|███▊      | 537/1403 [07:55<14:17,  1.01it/s]
#
#
#  38%|███▊      | 538/1403 [07:57<14:42,  1.02s/it]
#
#
#  38%|███▊      | 539/1403 [07:58<14:44,  1.02s/it]
#
#
#  38%|███▊      | 540/1403 [07:59<14:26,  1.00s/it]
#
#
#  39%|███▊      | 541/1403 [08:00<14:58,  1.04s/it]
#
#
#  39%|███▊      | 542/1403 [08:01<14:51,  1.04s/it]
#
#
#  39%|███▊      | 543/1403 [08:02<14:19,  1.00it/s]
#
#
#  39%|███▉      | 544/1403 [08:03<15:12,  1.06s/it]
#
#
#  39%|███▉      | 545/1403 [08:04<14:02,  1.02it/s]
#
#
#  39%|███▉      | 546/1403 [08:05<13:53,  1.03it/s]
#
#
#  39%|███▉      | 547/1403 [08:06<14:20,  1.00s/it]
#
#
#  39%|███▉      | 548/1403 [08:07<14:01,  1.02it/s]
#
#
#  39%|███▉      | 549/1403 [08:08<14:19,  1.01s/it]
#
#
#  39%|███▉      | 550/1403 [08:09<14:02,  1.01it/s]
#
#
#  39%|███▉      | 551/1403 [08:10<13:49,  1.03it/s]
#
#
#  39%|███▉      | 552/1403 [08:10<13:44,  1.03it/s]
#
#
#  39%|███▉      | 553/1403 [08:11<13:48,  1.03it/s]
#
#
#  39%|███▉      | 554/1403 [08:13<15:03,  1.06s/it]
#
#
#  40%|███▉      | 555/1403 [08:14<15:34,  1.10s/it]
#
#
#  40%|███▉      | 556/1403 [08:15<14:15,  1.01s/it]
#
#
#  40%|███▉      | 557/1403 [08:16<13:46,  1.02it/s]
#
#
#  40%|███▉      | 558/1403 [08:17<14:01,  1.00it/s]
#
#
#  40%|███▉      | 559/1403 [08:18<14:18,  1.02s/it]
#
#
#  40%|███▉      | 560/1403 [08:19<13:58,  1.00it/s]
#
#
#  40%|███▉      | 561/1403 [08:20<14:18,  1.02s/it]
#
#
#  40%|████      | 562/1403 [08:21<13:58,  1.00it/s]
#
#
#  40%|████      | 563/1403 [08:22<14:02,  1.00s/it]
#
#
#  40%|████      | 564/1403 [08:23<13:57,  1.00it/s]
#
#
#  40%|████      | 565/1403 [08:24<13:56,  1.00it/s]
#
#
#  40%|████      | 566/1403 [08:25<13:56,  1.00it/s]
#
#
#  40%|████      | 567/1403 [08:26<14:15,  1.02s/it]
#
#
#  40%|████      | 568/1403 [08:27<14:43,  1.06s/it]
#
#
#  41%|████      | 569/1403 [08:28<14:39,  1.05s/it]
#
#
#  41%|████      | 570/1403 [08:29<14:58,  1.08s/it]
#
#
#  41%|████      | 571/1403 [08:30<15:24,  1.11s/it]
#
#
#  41%|████      | 572/1403 [08:33<20:07,  1.45s/it]
#
#
#  41%|████      | 573/1403 [08:34<18:35,  1.34s/it]
#
#
#  41%|████      | 574/1403 [08:34<16:13,  1.17s/it]
#
#
#  41%|████      | 575/1403 [08:36<15:57,  1.16s/it]
#
#
#  41%|████      | 576/1403 [08:37<16:15,  1.18s/it]
#
#
#  41%|████      | 577/1403 [08:38<14:38,  1.06s/it]
#
#
#  41%|████      | 578/1403 [08:38<13:36,  1.01it/s]
#
#
#  41%|████▏     | 579/1403 [08:39<13:47,  1.00s/it]
#
#
#  41%|████▏     | 580/1403 [08:40<13:56,  1.02s/it]
#
#
#  41%|████▏     | 581/1403 [08:41<13:38,  1.00it/s]
#
#
#  41%|████▏     | 582/1403 [08:42<14:05,  1.03s/it]
#
#
#  42%|████▏     | 583/1403 [08:44<14:34,  1.07s/it]
#
#
#  42%|████▏     | 584/1403 [08:45<14:30,  1.06s/it]
#
#
#  42%|████▏     | 585/1403 [08:46<16:26,  1.21s/it]
#
#
#  42%|████▏     | 586/1403 [08:47<15:59,  1.17s/it]
#
#
#  42%|████▏     | 587/1403 [08:48<15:36,  1.15s/it]
#
#
#  42%|████▏     | 588/1403 [08:50<15:41,  1.15s/it]
#
#
#  42%|████▏     | 589/1403 [08:51<14:48,  1.09s/it]
#
#
#  42%|████▏     | 590/1403 [08:51<14:03,  1.04s/it]
#
#
#  42%|████▏     | 591/1403 [08:52<13:23,  1.01it/s]
#
#
#  42%|████▏     | 592/1403 [08:53<13:12,  1.02it/s]
#
#
#  42%|████▏     | 593/1403 [08:54<12:31,  1.08it/s]
#
#
#  42%|████▏     | 594/1403 [08:55<11:53,  1.13it/s]
#
#
#  42%|████▏     | 595/1403 [08:56<13:18,  1.01it/s]
#
#
#  42%|████▏     | 596/1403 [08:57<13:47,  1.03s/it]
#
#
#  43%|████▎     | 597/1403 [08:58<14:09,  1.05s/it]
#
#
#  43%|████▎     | 598/1403 [08:59<13:44,  1.02s/it]
#
#
#  43%|████▎     | 599/1403 [09:00<13:01,  1.03it/s]
#
#
#  43%|████▎     | 600/1403 [09:01<12:59,  1.03it/s]
#
#
#  43%|████▎     | 601/1403 [09:02<13:49,  1.03s/it]
#
#
#  43%|████▎     | 602/1403 [09:03<13:55,  1.04s/it]
#
#
#  43%|████▎     | 603/1403 [09:04<14:04,  1.06s/it]
#
#
#  43%|████▎     | 604/1403 [09:05<13:29,  1.01s/it]
#
#
#  43%|████▎     | 605/1403 [09:07<14:13,  1.07s/it]
#
#
#  43%|████▎     | 606/1403 [09:08<15:17,  1.15s/it]
#
#
#  43%|████▎     | 607/1403 [09:09<14:54,  1.12s/it]
#
#
#  43%|████▎     | 608/1403 [09:10<14:14,  1.07s/it]
#
#
#  43%|████▎     | 609/1403 [09:11<14:35,  1.10s/it]
#
#
#  43%|████▎     | 610/1403 [09:12<13:48,  1.04s/it]
#
#
#  44%|████▎     | 611/1403 [09:13<14:07,  1.07s/it]
#
#
#  44%|████▎     | 612/1403 [09:14<14:53,  1.13s/it]
#
#
#  44%|████▎     | 613/1403 [09:16<15:10,  1.15s/it]
#
#
#  44%|████▍     | 614/1403 [09:17<14:52,  1.13s/it]
#
#
#  44%|████▍     | 615/1403 [09:19<18:07,  1.38s/it]
#
#
#  44%|████▍     | 616/1403 [09:20<16:37,  1.27s/it]
#
#
#  44%|████▍     | 617/1403 [09:21<15:23,  1.18s/it]
#
#
#  44%|████▍     | 618/1403 [09:22<14:53,  1.14s/it]
#
#
#  44%|████▍     | 619/1403 [09:23<14:54,  1.14s/it]
#
#
#  44%|████▍     | 620/1403 [09:24<14:17,  1.10s/it]
#
#
#  44%|████▍     | 621/1403 [09:25<13:26,  1.03s/it]
#
#
#  44%|████▍     | 622/1403 [09:26<14:06,  1.08s/it]
#
#
#  44%|████▍     | 623/1403 [09:27<14:04,  1.08s/it]
#
#
#  44%|████▍     | 624/1403 [09:28<13:02,  1.01s/it]
#
#
#  45%|████▍     | 625/1403 [09:29<12:29,  1.04it/s]
#
#
#  45%|████▍     | 626/1403 [09:30<12:41,  1.02it/s]
#
#
#  45%|████▍     | 627/1403 [09:31<13:20,  1.03s/it]
#
#
#  45%|████▍     | 628/1403 [09:32<13:58,  1.08s/it]
#
#
#  45%|████▍     | 629/1403 [09:33<14:11,  1.10s/it]
#
#
#  45%|████▍     | 630/1403 [09:34<13:42,  1.06s/it]
#
#
#  45%|████▍     | 631/1403 [09:35<13:38,  1.06s/it]
#
#
#  45%|████▌     | 632/1403 [09:36<13:34,  1.06s/it]
#
#
#  45%|████▌     | 633/1403 [09:37<13:40,  1.07s/it]
#
#
#  45%|████▌     | 634/1403 [09:38<12:36,  1.02it/s]
#
#
#  45%|████▌     | 635/1403 [09:39<12:47,  1.00it/s]
#
#
#  45%|████▌     | 636/1403 [09:40<13:52,  1.09s/it]
#
#
#  45%|████▌     | 637/1403 [09:42<13:46,  1.08s/it]
#
#
#  45%|████▌     | 638/1403 [09:42<12:07,  1.05it/s]
#
#
#  46%|████▌     | 639/1403 [09:43<11:35,  1.10it/s]
#
#
#  46%|████▌     | 640/1403 [09:44<11:25,  1.11it/s]
#
#
#  46%|████▌     | 641/1403 [09:45<11:30,  1.10it/s]
#
#
#  46%|████▌     | 642/1403 [09:46<10:53,  1.16it/s]
#
#
#  46%|████▌     | 643/1403 [09:47<11:42,  1.08it/s]
#
#
#  46%|████▌     | 644/1403 [09:48<12:37,  1.00it/s]
#
#
#  46%|████▌     | 645/1403 [09:49<12:41,  1.01s/it]
#
#
#  46%|████▌     | 646/1403 [09:50<12:51,  1.02s/it]
#
#
#  46%|████▌     | 647/1403 [09:51<12:23,  1.02it/s]
#
#
#  46%|████▌     | 648/1403 [09:52<12:11,  1.03it/s]
#
#
#  46%|████▋     | 649/1403 [09:53<12:46,  1.02s/it]
#
#
#  46%|████▋     | 650/1403 [09:54<13:04,  1.04s/it]
#
#
#  46%|████▋     | 651/1403 [09:55<13:17,  1.06s/it]
#
#
#  46%|████▋     | 652/1403 [09:56<12:38,  1.01s/it]
#
#
#  47%|████▋     | 653/1403 [09:57<12:56,  1.04s/it]
#
#
#  47%|████▋     | 654/1403 [09:58<13:09,  1.05s/it]
#
#
#  47%|████▋     | 655/1403 [09:59<12:08,  1.03it/s]
#
#
#  47%|████▋     | 656/1403 [10:00<13:16,  1.07s/it]
#
#
#  47%|████▋     | 657/1403 [10:01<12:27,  1.00s/it]
#
#
#  47%|████▋     | 658/1403 [10:02<12:29,  1.01s/it]
#
#
#  47%|████▋     | 659/1403 [10:03<12:04,  1.03it/s]
#
#
#  47%|████▋     | 660/1403 [10:04<12:49,  1.04s/it]
#
#
#  47%|████▋     | 661/1403 [10:05<12:48,  1.04s/it]
#
#
#  47%|████▋     | 662/1403 [10:06<12:18,  1.00it/s]
#
#
#  47%|████▋     | 663/1403 [10:07<12:28,  1.01s/it]
#
#
#  47%|████▋     | 664/1403 [10:08<12:39,  1.03s/it]
#
#
#  47%|████▋     | 665/1403 [10:09<13:28,  1.10s/it]
#
#
#  47%|████▋     | 666/1403 [10:11<14:04,  1.15s/it]
#
#
#  48%|████▊     | 667/1403 [10:12<14:07,  1.15s/it]
#
#
#  48%|████▊     | 668/1403 [10:13<12:49,  1.05s/it]
#
#
#  48%|████▊     | 669/1403 [10:14<12:14,  1.00s/it]
#
#
#  48%|████▊     | 670/1403 [10:15<13:20,  1.09s/it]
#
#
#  48%|████▊     | 671/1403 [10:16<12:39,  1.04s/it]
#
#
#  48%|████▊     | 672/1403 [10:17<13:19,  1.09s/it]
#
#
#  48%|████▊     | 673/1403 [10:18<12:18,  1.01s/it]
#
#
#  48%|████▊     | 674/1403 [10:19<12:01,  1.01it/s]
#
#
#  48%|████▊     | 675/1403 [10:20<11:47,  1.03it/s]
#
#
#  48%|████▊     | 676/1403 [10:21<11:41,  1.04it/s]
#
#
#  48%|████▊     | 677/1403 [10:22<11:32,  1.05it/s]
#
#
#  48%|████▊     | 678/1403 [10:22<11:25,  1.06it/s]
#
#
#  48%|████▊     | 679/1403 [10:23<11:08,  1.08it/s]
#
#
#  48%|████▊     | 680/1403 [10:24<11:15,  1.07it/s]
#
#
#  49%|████▊     | 681/1403 [10:25<11:25,  1.05it/s]
#
#
#  49%|████▊     | 682/1403 [10:26<11:31,  1.04it/s]
#
#
#  49%|████▊     | 683/1403 [10:27<11:16,  1.06it/s]
#
#
#  49%|████▉     | 684/1403 [10:28<11:18,  1.06it/s]
#
#
#  49%|████▉     | 685/1403 [10:29<11:47,  1.01it/s]
#
#
#  49%|████▉     | 686/1403 [10:30<11:33,  1.03it/s]
#
#
#  49%|████▉     | 687/1403 [10:31<11:50,  1.01it/s]
#
#
#  49%|████▉     | 688/1403 [10:32<12:23,  1.04s/it]
#
#
#  49%|████▉     | 689/1403 [10:33<12:44,  1.07s/it]
#
#
#  49%|████▉     | 690/1403 [10:34<12:00,  1.01s/it]
#
#
#  49%|████▉     | 691/1403 [10:35<11:06,  1.07it/s]
#
#
#  49%|████▉     | 692/1403 [10:36<11:05,  1.07it/s]
#
#
#  49%|████▉     | 693/1403 [10:37<11:50,  1.00s/it]
#
#
#  49%|████▉     | 694/1403 [10:38<12:23,  1.05s/it]
#
#
#  50%|████▉     | 695/1403 [10:39<12:09,  1.03s/it]
#
#
#  50%|████▉     | 696/1403 [10:41<12:57,  1.10s/it]
#
#
#  50%|████▉     | 697/1403 [10:42<12:32,  1.07s/it]
#
#
#  50%|████▉     | 698/1403 [10:43<12:08,  1.03s/it]
#
#
#  50%|████▉     | 699/1403 [10:43<11:13,  1.04it/s]
#
#
#  50%|████▉     | 700/1403 [10:45<12:14,  1.04s/it]
#
#
#  50%|████▉     | 701/1403 [10:45<11:35,  1.01it/s]
#
#
#  50%|█████     | 702/1403 [10:46<10:44,  1.09it/s]
#
#
#  50%|█████     | 703/1403 [10:47<10:33,  1.10it/s]
#
#
#  50%|█████     | 704/1403 [10:48<10:31,  1.11it/s]
#
#
#  50%|█████     | 705/1403 [10:49<11:13,  1.04it/s]
#
#
#  50%|█████     | 706/1403 [10:50<11:50,  1.02s/it]
#
#
#  50%|█████     | 707/1403 [10:51<12:02,  1.04s/it]
#
#
#  50%|█████     | 708/1403 [10:52<11:45,  1.02s/it]
#
#
#  51%|█████     | 709/1403 [10:53<11:06,  1.04it/s]
#
#
#  51%|█████     | 710/1403 [10:54<11:24,  1.01it/s]
#
#
#  51%|█████     | 711/1403 [10:55<11:38,  1.01s/it]
#
#
#  51%|█████     | 712/1403 [10:56<12:09,  1.06s/it]
#
#
#  51%|█████     | 713/1403 [10:57<11:25,  1.01it/s]
#
#
#  51%|█████     | 714/1403 [10:58<11:09,  1.03it/s]
#
#
#  51%|█████     | 715/1403 [10:59<10:23,  1.10it/s]
#
#
#  51%|█████     | 716/1403 [11:00<10:48,  1.06it/s]
#
#
#  51%|█████     | 717/1403 [11:01<10:38,  1.07it/s]
#
#
#  51%|█████     | 718/1403 [11:02<09:53,  1.15it/s]
#
#
#  51%|█████     | 719/1403 [11:03<10:55,  1.04it/s]
#
#
#  51%|█████▏    | 720/1403 [11:04<10:58,  1.04it/s]
#
#
#  51%|█████▏    | 721/1403 [11:05<10:52,  1.05it/s]
#
#
#  51%|█████▏    | 722/1403 [11:06<11:54,  1.05s/it]
#
#
#  52%|█████▏    | 723/1403 [11:07<11:30,  1.02s/it]
#
#
#  52%|█████▏    | 724/1403 [11:08<10:53,  1.04it/s]
#
#
#  52%|█████▏    | 725/1403 [11:09<11:06,  1.02it/s]
#
#
#  52%|█████▏    | 726/1403 [11:10<11:17,  1.00s/it]
#
#
#  52%|█████▏    | 727/1403 [11:11<11:32,  1.02s/it]
#
#
#  52%|█████▏    | 728/1403 [11:12<10:44,  1.05it/s]
#
#
#  52%|█████▏    | 729/1403 [11:13<11:06,  1.01it/s]
#
#
#  52%|█████▏    | 730/1403 [11:14<11:03,  1.01it/s]
#
#
#  52%|█████▏    | 731/1403 [11:14<10:32,  1.06it/s]
#
#
#  52%|█████▏    | 732/1403 [11:15<10:18,  1.09it/s]
#
#
#  52%|█████▏    | 733/1403 [11:16<10:50,  1.03it/s]
#
#
#  52%|█████▏    | 734/1403 [11:18<11:22,  1.02s/it]
#
#
#  52%|█████▏    | 735/1403 [11:19<12:27,  1.12s/it]
#
#
#  52%|█████▏    | 736/1403 [11:20<11:34,  1.04s/it]
#
#
#  53%|█████▎    | 737/1403 [11:20<10:17,  1.08it/s]
#
#
#  53%|█████▎    | 738/1403 [11:21<10:38,  1.04it/s]
#
#
#  53%|█████▎    | 739/1403 [11:23<11:17,  1.02s/it]
#
#
#  53%|█████▎    | 740/1403 [11:24<10:50,  1.02it/s]
#
#
#  53%|█████▎    | 741/1403 [11:25<11:04,  1.00s/it]
#
#
#  53%|█████▎    | 742/1403 [11:26<10:59,  1.00it/s]
#
#
#  53%|█████▎    | 743/1403 [11:27<11:04,  1.01s/it]
#
#
#  53%|█████▎    | 744/1403 [11:28<11:12,  1.02s/it]
#
#
#  53%|█████▎    | 745/1403 [11:29<11:20,  1.03s/it]
#
#
#  53%|█████▎    | 746/1403 [11:30<10:50,  1.01it/s]
#
#
#  53%|█████▎    | 747/1403 [11:31<10:55,  1.00it/s]
#
#
#  53%|█████▎    | 748/1403 [11:31<10:24,  1.05it/s]
#
#
#  53%|█████▎    | 749/1403 [11:33<10:58,  1.01s/it]
#
#
#  53%|█████▎    | 750/1403 [11:33<09:53,  1.10it/s]
#
#
#  54%|█████▎    | 751/1403 [11:34<10:08,  1.07it/s]
#
#
#  54%|█████▎    | 752/1403 [11:35<10:42,  1.01it/s]
#
#
#  54%|█████▎    | 753/1403 [11:36<10:26,  1.04it/s]
#
#
#  54%|█████▎    | 754/1403 [11:37<10:35,  1.02it/s]
#
#
#  54%|█████▍    | 755/1403 [11:38<10:58,  1.02s/it]
#
#
#  54%|█████▍    | 756/1403 [11:39<10:31,  1.02it/s]
#
#
#  54%|█████▍    | 757/1403 [11:40<10:11,  1.06it/s]
#
#
#  54%|█████▍    | 758/1403 [11:41<10:13,  1.05it/s]
#
#
#  54%|█████▍    | 759/1403 [11:42<10:02,  1.07it/s]
#
#
#  54%|█████▍    | 760/1403 [11:43<10:12,  1.05it/s]
#
#
#  54%|█████▍    | 761/1403 [11:44<10:19,  1.04it/s]
#
#
#  54%|█████▍    | 762/1403 [11:45<10:22,  1.03it/s]
#
#
#  54%|█████▍    | 763/1403 [11:46<09:35,  1.11it/s]
#
#
#  54%|█████▍    | 764/1403 [11:47<09:12,  1.16it/s]
#
#
#  55%|█████▍    | 765/1403 [11:48<10:15,  1.04it/s]
#
#
#  55%|█████▍    | 766/1403 [11:49<11:05,  1.04s/it]
#
#
#  55%|█████▍    | 767/1403 [11:50<09:29,  1.12it/s]
#
#
#  55%|█████▍    | 768/1403 [11:51<10:12,  1.04it/s]
#
#
#  55%|█████▍    | 769/1403 [11:52<11:04,  1.05s/it]
#
#
#  55%|█████▍    | 770/1403 [11:53<10:45,  1.02s/it]
#
#
#  55%|█████▍    | 771/1403 [11:54<10:16,  1.03it/s]
#
#
#  55%|█████▌    | 772/1403 [11:55<10:53,  1.04s/it]
#
#
#  55%|█████▌    | 773/1403 [11:56<10:16,  1.02it/s]
#
#
#  55%|█████▌    | 774/1403 [11:57<11:23,  1.09s/it]
#
#
#  55%|█████▌    | 775/1403 [11:58<10:59,  1.05s/it]
#
#
#  55%|█████▌    | 776/1403 [11:59<09:47,  1.07it/s]
#
#
#  55%|█████▌    | 777/1403 [12:00<09:21,  1.12it/s]
#
#
#  55%|█████▌    | 778/1403 [12:00<09:33,  1.09it/s]
#
#
#  56%|█████▌    | 779/1403 [12:01<08:42,  1.19it/s]
#
#
#  56%|█████▌    | 780/1403 [12:02<09:12,  1.13it/s]
#
#
#  56%|█████▌    | 781/1403 [12:04<12:25,  1.20s/it]
#
#
#  56%|█████▌    | 782/1403 [12:06<14:56,  1.44s/it]
#
#
#  56%|█████▌    | 783/1403 [12:07<13:07,  1.27s/it]
#
#
#  56%|█████▌    | 784/1403 [12:08<12:05,  1.17s/it]
#
#
#  56%|█████▌    | 785/1403 [12:09<11:21,  1.10s/it]
#
#
#  56%|█████▌    | 786/1403 [12:10<11:28,  1.12s/it]
#
#
#  56%|█████▌    | 787/1403 [12:11<11:50,  1.15s/it]
#
#
#  56%|█████▌    | 788/1403 [12:12<11:08,  1.09s/it]
#
#
#  56%|█████▌    | 789/1403 [12:13<10:32,  1.03s/it]
#
#
#  56%|█████▋    | 790/1403 [12:14<10:23,  1.02s/it]
#
#
#  56%|█████▋    | 791/1403 [12:15<10:47,  1.06s/it]
#
#
#  56%|█████▋    | 792/1403 [12:16<10:29,  1.03s/it]
#
#
#  57%|█████▋    | 793/1403 [12:17<10:25,  1.03s/it]
#
#
#  57%|█████▋    | 794/1403 [12:18<10:23,  1.02s/it]
#
#
#  57%|█████▋    | 795/1403 [12:19<10:29,  1.04s/it]
#
#
#  57%|█████▋    | 796/1403 [12:20<10:20,  1.02s/it]
#
#
#  57%|█████▋    | 797/1403 [12:21<09:48,  1.03it/s]
#
#
#  57%|█████▋    | 798/1403 [12:22<09:24,  1.07it/s]
#
#
#  57%|█████▋    | 799/1403 [12:23<09:15,  1.09it/s]
#
#
#  57%|█████▋    | 800/1403 [12:24<09:13,  1.09it/s]
#
#
#  57%|█████▋    | 801/1403 [12:25<09:06,  1.10it/s]
#
#
#  57%|█████▋    | 802/1403 [12:26<10:25,  1.04s/it]
#
#
#  57%|█████▋    | 803/1403 [12:27<10:08,  1.01s/it]
#
#
#  57%|█████▋    | 804/1403 [12:28<09:11,  1.09it/s]
#
#
#  57%|█████▋    | 805/1403 [12:29<09:22,  1.06it/s]
#
#
#  57%|█████▋    | 806/1403 [12:29<09:05,  1.09it/s]
#
#
#  58%|█████▊    | 807/1403 [12:30<08:32,  1.16it/s]
#
#
#  58%|█████▊    | 808/1403 [12:31<08:45,  1.13it/s]
#
#
#  58%|█████▊    | 809/1403 [12:32<08:50,  1.12it/s]
#
#
#  58%|█████▊    | 810/1403 [12:33<07:34,  1.31it/s]
#
#
#  58%|█████▊    | 811/1403 [12:33<07:49,  1.26it/s]
#
#
#  58%|█████▊    | 812/1403 [12:34<08:12,  1.20it/s]
#
#
#  58%|█████▊    | 813/1403 [12:35<08:37,  1.14it/s]
#
#
#  58%|█████▊    | 814/1403 [12:36<09:30,  1.03it/s]
#
#
#  58%|█████▊    | 815/1403 [12:38<09:56,  1.01s/it]
#
#
#  58%|█████▊    | 816/1403 [12:38<09:36,  1.02it/s]
#
#
#  58%|█████▊    | 817/1403 [12:39<09:04,  1.08it/s]
#
#
#  58%|█████▊    | 818/1403 [12:40<09:30,  1.03it/s]
#
#
#  58%|█████▊    | 819/1403 [12:41<09:27,  1.03it/s]
#
#
#  58%|█████▊    | 820/1403 [12:42<09:45,  1.00s/it]
#
#
#  59%|█████▊    | 821/1403 [12:43<09:05,  1.07it/s]
#
#
#  59%|█████▊    | 822/1403 [12:44<09:26,  1.03it/s]
#
#
#  59%|█████▊    | 823/1403 [12:45<08:56,  1.08it/s]
#
#
#  59%|█████▊    | 824/1403 [12:46<08:45,  1.10it/s]
#
#
#  59%|█████▉    | 825/1403 [12:47<09:20,  1.03it/s]
#
#
#  59%|█████▉    | 826/1403 [12:48<08:54,  1.08it/s]
#
#
#  59%|█████▉    | 827/1403 [12:49<08:59,  1.07it/s]
#
#
#  59%|█████▉    | 828/1403 [12:50<08:55,  1.07it/s]
#
#
#  59%|█████▉    | 829/1403 [12:51<08:47,  1.09it/s]
#
#
#  59%|█████▉    | 830/1403 [12:52<09:00,  1.06it/s]
#
#
#  59%|█████▉    | 831/1403 [12:53<09:33,  1.00s/it]
#
#
#  59%|█████▉    | 832/1403 [12:54<09:24,  1.01it/s]
#
#
#  59%|█████▉    | 833/1403 [12:55<09:33,  1.01s/it]
#
#
#  59%|█████▉    | 834/1403 [12:56<09:26,  1.00it/s]
#
#
#  60%|█████▉    | 835/1403 [12:57<09:21,  1.01it/s]
#
#
#  60%|█████▉    | 836/1403 [12:58<09:46,  1.03s/it]
#
#
#  60%|█████▉    | 837/1403 [12:59<09:06,  1.04it/s]
#
#
#  60%|█████▉    | 838/1403 [13:00<09:06,  1.03it/s]
#
#
#  60%|█████▉    | 839/1403 [13:01<09:49,  1.05s/it]
#
#
#  60%|█████▉    | 840/1403 [13:02<09:44,  1.04s/it]
#
#
#  60%|█████▉    | 841/1403 [13:03<10:12,  1.09s/it]
#
#
#  60%|██████    | 842/1403 [13:04<10:03,  1.08s/it]
#
#
#  60%|██████    | 843/1403 [13:05<09:25,  1.01s/it]
#
#
#  60%|██████    | 844/1403 [13:06<09:58,  1.07s/it]
#
#
#  60%|██████    | 845/1403 [13:07<10:01,  1.08s/it]
#
#
#  60%|██████    | 846/1403 [13:08<09:53,  1.07s/it]
#
#
#  60%|██████    | 847/1403 [13:09<09:45,  1.05s/it]
#
#
#  60%|██████    | 848/1403 [13:10<09:40,  1.05s/it]
#
#
#  61%|██████    | 849/1403 [13:11<09:15,  1.00s/it]
#
#
#  61%|██████    | 850/1403 [13:12<09:20,  1.01s/it]
#
#
#  61%|██████    | 851/1403 [13:14<09:58,  1.08s/it]
#
#
#  61%|██████    | 852/1403 [13:15<10:39,  1.16s/it]
#
#
#  61%|██████    | 853/1403 [13:16<10:29,  1.14s/it]
#
#
#  61%|██████    | 854/1403 [13:17<10:35,  1.16s/it]
#
#
#  61%|██████    | 855/1403 [13:18<10:28,  1.15s/it]
#
#
#  61%|██████    | 856/1403 [13:19<10:21,  1.14s/it]
#
#
#  61%|██████    | 857/1403 [13:21<10:47,  1.19s/it]
#
#
#  61%|██████    | 858/1403 [13:21<09:06,  1.00s/it]
#
#
#  61%|██████    | 859/1403 [13:22<08:36,  1.05it/s]
#
#
#  61%|██████▏   | 860/1403 [13:24<09:49,  1.09s/it]
#
#
#  61%|██████▏   | 861/1403 [13:25<10:02,  1.11s/it]
#
#
#  61%|██████▏   | 862/1403 [13:26<09:39,  1.07s/it]
#
#
#  62%|██████▏   | 863/1403 [13:26<07:58,  1.13it/s]
#
#
#  62%|██████▏   | 864/1403 [13:27<08:35,  1.05it/s]
#
#
#  62%|██████▏   | 865/1403 [13:29<09:41,  1.08s/it]
#
#
#  62%|██████▏   | 866/1403 [13:30<09:52,  1.10s/it]
#
#
#  62%|██████▏   | 867/1403 [13:31<09:08,  1.02s/it]
#
#
#  62%|██████▏   | 868/1403 [13:32<09:20,  1.05s/it]
#
#
#  62%|██████▏   | 869/1403 [13:33<09:17,  1.04s/it]
#
#
#  62%|██████▏   | 870/1403 [13:34<09:11,  1.04s/it]
#
#
#  62%|██████▏   | 871/1403 [13:35<08:31,  1.04it/s]
#
#
#  62%|██████▏   | 872/1403 [13:36<08:57,  1.01s/it]
#
#
#  62%|██████▏   | 873/1403 [13:37<08:41,  1.02it/s]
#
#
#  62%|██████▏   | 874/1403 [13:38<08:55,  1.01s/it]
#
#
#  62%|██████▏   | 875/1403 [13:39<08:50,  1.00s/it]
#
#
#  62%|██████▏   | 876/1403 [13:40<09:15,  1.05s/it]
#
#
#  63%|██████▎   | 877/1403 [13:41<08:38,  1.01it/s]
#
#
#  63%|██████▎   | 878/1403 [13:42<08:25,  1.04it/s]
#
#
#  63%|██████▎   | 879/1403 [13:42<08:05,  1.08it/s]
#
#
#  63%|██████▎   | 880/1403 [13:43<08:06,  1.07it/s]
#
#
#  63%|██████▎   | 881/1403 [13:44<07:46,  1.12it/s]
#
#
#  63%|██████▎   | 882/1403 [13:45<07:05,  1.22it/s]
#
#
#  63%|██████▎   | 883/1403 [13:46<07:03,  1.23it/s]
#
#
#  63%|██████▎   | 884/1403 [13:47<07:59,  1.08it/s]
#
#
#  63%|██████▎   | 885/1403 [13:48<08:01,  1.07it/s]
#
#
#  63%|██████▎   | 886/1403 [13:49<08:15,  1.04it/s]
#
#
#  63%|██████▎   | 887/1403 [13:50<07:40,  1.12it/s]
#
#
#  63%|██████▎   | 888/1403 [13:50<07:42,  1.11it/s]
#
#
#  63%|██████▎   | 889/1403 [13:51<07:22,  1.16it/s]
#
#
#  63%|██████▎   | 890/1403 [13:52<07:23,  1.16it/s]
#
#
#  64%|██████▎   | 891/1403 [13:53<08:02,  1.06it/s]
#
#
#  64%|██████▎   | 892/1403 [13:54<08:20,  1.02it/s]
#
#
#  64%|██████▎   | 893/1403 [13:56<09:16,  1.09s/it]
#
#
#  64%|██████▎   | 894/1403 [13:57<09:27,  1.12s/it]
#
#
#  64%|██████▍   | 895/1403 [13:58<09:32,  1.13s/it]
#
#
#  64%|██████▍   | 896/1403 [13:59<09:30,  1.13s/it]
#
#
#  64%|██████▍   | 897/1403 [14:00<10:11,  1.21s/it]
#
#
#  64%|██████▍   | 898/1403 [14:02<09:55,  1.18s/it]
#
#
#  64%|██████▍   | 899/1403 [14:02<08:59,  1.07s/it]
#
#
#  64%|██████▍   | 900/1403 [14:03<08:07,  1.03it/s]
#
#
#  64%|██████▍   | 901/1403 [14:04<08:33,  1.02s/it]
#
#
#  64%|██████▍   | 902/1403 [14:05<08:44,  1.05s/it]
#
#
#  64%|██████▍   | 903/1403 [14:07<09:12,  1.10s/it]
#
#
#  64%|██████▍   | 904/1403 [14:08<08:51,  1.06s/it]
#
#
#  65%|██████▍   | 905/1403 [14:09<08:40,  1.05s/it]
#
#
#  65%|██████▍   | 906/1403 [14:10<08:20,  1.01s/it]
#
#
#  65%|██████▍   | 907/1403 [14:11<08:13,  1.00it/s]
#
#
# ...
#
#
#  79%|███████▉  | 1108/1403 [17:21<04:37,  1.06it/s]
#
#
#  79%|███████▉  | 1109/1403 [17:22<04:23,  1.11it/s]
#
#
#  79%|███████▉  | 1110/1403 [17:23<04:20,  1.13it/s]
#
#
#  79%|███████▉  | 1111/1403 [17:24<04:44,  1.03it/s]
#
#
#  79%|███████▉  | 1112/1403 [17:25<04:35,  1.06it/s]
#
#
#  79%|███████▉  | 1113/1403 [17:26<04:39,  1.04it/s]
#
#
#  79%|███████▉  | 1114/1403 [17:27<04:27,  1.08it/s]
#
#
#  79%|███████▉  | 1115/1403 [17:28<04:32,  1.06it/s]
#
#
#  80%|███████▉  | 1116/1403 [17:29<04:45,  1.00it/s]
#
#
#  80%|███████▉  | 1117/1403 [17:30<04:41,  1.02it/s]
#
#
#  80%|███████▉  | 1118/1403 [17:31<04:37,  1.03it/s]
#
#
#  80%|███████▉  | 1119/1403 [17:32<04:52,  1.03s/it]
#
#
#  80%|███████▉  | 1120/1403 [17:33<04:59,  1.06s/it]
#
#
#  80%|███████▉  | 1121/1403 [17:34<04:45,  1.01s/it]
#
#
#  80%|███████▉  | 1122/1403 [17:35<04:46,  1.02s/it]
#
#
#  80%|████████  | 1123/1403 [17:36<04:52,  1.04s/it]
#
#
#  80%|████████  | 1124/1403 [17:37<04:56,  1.06s/it]
#
#
#  80%|████████  | 1125/1403 [17:38<04:39,  1.01s/it]
#
#
#  80%|████████  | 1126/1403 [17:39<04:08,  1.11it/s]
#
#
#  80%|████████  | 1127/1403 [17:39<03:28,  1.32it/s]
#
#
#  80%|████████  | 1128/1403 [17:40<03:31,  1.30it/s]
#
#
#  80%|████████  | 1129/1403 [17:41<03:39,  1.25it/s]
#
#
#  81%|████████  | 1130/1403 [17:42<04:02,  1.13it/s]
#
#
#  81%|████████  | 1131/1403 [17:43<03:53,  1.17it/s]
#
#
#  81%|████████  | 1132/1403 [17:43<03:51,  1.17it/s]
#
#
#  81%|████████  | 1133/1403 [17:44<03:42,  1.22it/s]
#
#
#  81%|████████  | 1134/1403 [17:45<03:55,  1.14it/s]
#
#
#  81%|████████  | 1135/1403 [17:46<03:48,  1.17it/s]
#
#
#  81%|████████  | 1136/1403 [17:47<03:52,  1.15it/s]
#
#
#  81%|████████  | 1137/1403 [17:48<03:48,  1.16it/s]
#
#
#  81%|████████  | 1138/1403 [17:49<04:08,  1.07it/s]
#
#
#  81%|████████  | 1139/1403 [17:50<04:06,  1.07it/s]
#
#
#  81%|████████▏ | 1140/1403 [17:51<04:11,  1.05it/s]
#
#
#  81%|████████▏ | 1141/1403 [17:52<03:58,  1.10it/s]
#
#
#  81%|████████▏ | 1142/1403 [17:52<03:56,  1.10it/s]
#
#
#  81%|████████▏ | 1143/1403 [17:54<04:05,  1.06it/s]
#
#
#  82%|████████▏ | 1144/1403 [17:55<04:14,  1.02it/s]
#
#
#  82%|████████▏ | 1145/1403 [17:55<03:54,  1.10it/s]
#
#
#  82%|████████▏ | 1146/1403 [17:56<03:32,  1.21it/s]
#
#
#  82%|████████▏ | 1147/1403 [17:57<03:44,  1.14it/s]
#
#
#  82%|████████▏ | 1148/1403 [17:58<03:58,  1.07it/s]
#
#
#  82%|████████▏ | 1149/1403 [17:59<03:50,  1.10it/s]
#
#
#  82%|████████▏ | 1150/1403 [18:00<03:48,  1.11it/s]
#
#
#  82%|████████▏ | 1151/1403 [18:01<03:53,  1.08it/s]
#
#
#  82%|████████▏ | 1152/1403 [18:01<03:29,  1.20it/s]
#
#
#  82%|████████▏ | 1153/1403 [18:02<03:32,  1.17it/s]
#
#
#  82%|████████▏ | 1154/1403 [18:03<03:57,  1.05it/s]
#
#
#  82%|████████▏ | 1155/1403 [18:04<03:20,  1.24it/s]
#
#
#  82%|████████▏ | 1156/1403 [18:05<03:32,  1.16it/s]
#
#
#  82%|████████▏ | 1157/1403 [18:06<03:57,  1.04it/s]
#
#
#  83%|████████▎ | 1158/1403 [18:07<03:36,  1.13it/s]
#
#
#  83%|████████▎ | 1159/1403 [18:08<03:32,  1.15it/s]
#
#
#  83%|████████▎ | 1160/1403 [18:09<03:48,  1.06it/s]
#
#
#  83%|████████▎ | 1161/1403 [18:11<05:25,  1.34s/it]
#
#
#  83%|████████▎ | 1162/1403 [18:12<05:15,  1.31s/it]
#
#
#  83%|████████▎ | 1163/1403 [18:13<04:54,  1.23s/it]
#
#
#  83%|████████▎ | 1164/1403 [18:15<04:58,  1.25s/it]
#
#
#  83%|████████▎ | 1165/1403 [18:15<04:17,  1.08s/it]
#
#
#  83%|████████▎ | 1166/1403 [18:16<04:07,  1.05s/it]
#
#
#  83%|████████▎ | 1167/1403 [18:17<03:57,  1.01s/it]
#
#
#  83%|████████▎ | 1168/1403 [18:18<03:56,  1.01s/it]
#
#
#  83%|████████▎ | 1169/1403 [18:19<03:36,  1.08it/s]
#
#
#  83%|████████▎ | 1170/1403 [18:20<03:31,  1.10it/s]
#
#
#  83%|████████▎ | 1171/1403 [18:21<03:35,  1.08it/s]
#
#
#  84%|████████▎ | 1172/1403 [18:22<03:49,  1.00it/s]
#
#
#  84%|████████▎ | 1173/1403 [18:23<03:35,  1.07it/s]
#
#
#  84%|████████▎ | 1174/1403 [18:24<03:33,  1.07it/s]
#
#
#  84%|████████▎ | 1175/1403 [18:25<03:41,  1.03it/s]
#
#
#  84%|████████▍ | 1176/1403 [18:26<03:43,  1.02it/s]
#
#
#  84%|████████▍ | 1177/1403 [18:27<03:35,  1.05it/s]
#
#
#  84%|████████▍ | 1178/1403 [18:28<03:47,  1.01s/it]
#
#
#  84%|████████▍ | 1179/1403 [18:29<03:39,  1.02it/s]
#
#
#  84%|████████▍ | 1180/1403 [18:29<03:31,  1.05it/s]
#
#
#  84%|████████▍ | 1181/1403 [18:30<03:26,  1.08it/s]
#
#
#  84%|████████▍ | 1182/1403 [18:31<03:25,  1.07it/s]
#
#
#  84%|████████▍ | 1183/1403 [18:32<03:11,  1.15it/s]
#
#
#  84%|████████▍ | 1184/1403 [18:33<03:08,  1.16it/s]
#
#
#  84%|████████▍ | 1185/1403 [18:34<03:07,  1.16it/s]
#
#
#  85%|████████▍ | 1186/1403 [18:35<03:13,  1.12it/s]
#
#
#  85%|████████▍ | 1187/1403 [18:35<03:03,  1.18it/s]
#
#
#  85%|████████▍ | 1188/1403 [18:36<03:01,  1.19it/s]
#
#
#  85%|████████▍ | 1189/1403 [18:37<02:57,  1.21it/s]
#
#
#  85%|████████▍ | 1190/1403 [18:38<03:13,  1.10it/s]
#
#
#  85%|████████▍ | 1191/1403 [18:39<03:24,  1.04it/s]
#
#
#  85%|████████▍ | 1192/1403 [18:40<03:13,  1.09it/s]
#
#
#  85%|████████▌ | 1193/1403 [18:41<03:36,  1.03s/it]
#
#
#  85%|████████▌ | 1194/1403 [18:42<03:17,  1.06it/s]
#
#
#  85%|████████▌ | 1195/1403 [18:43<03:29,  1.01s/it]
#
#
#  85%|████████▌ | 1196/1403 [18:44<03:19,  1.04it/s]
#
#
#  85%|████████▌ | 1197/1403 [18:45<03:19,  1.04it/s]
#
#
#  85%|████████▌ | 1198/1403 [18:46<03:13,  1.06it/s]
#
#
#  85%|████████▌ | 1199/1403 [18:47<03:15,  1.05it/s]
#
#
#  86%|████████▌ | 1200/1403 [18:48<03:14,  1.05it/s]
#
#
#  86%|████████▌ | 1201/1403 [18:49<03:09,  1.07it/s]
#
#
#  86%|████████▌ | 1202/1403 [18:50<03:22,  1.01s/it]
#
#
#  86%|████████▌ | 1203/1403 [18:51<03:27,  1.04s/it]
#
#
#  86%|████████▌ | 1204/1403 [18:51<02:46,  1.20it/s]
#
#
#  86%|████████▌ | 1205/1403 [18:52<02:47,  1.18it/s]
#
#
#  86%|████████▌ | 1206/1403 [18:53<02:43,  1.21it/s]
#
#
#  86%|████████▌ | 1207/1403 [18:54<02:37,  1.25it/s]
#
#
#  86%|████████▌ | 1208/1403 [18:55<02:43,  1.19it/s]
#
#
#  86%|████████▌ | 1209/1403 [18:56<02:51,  1.13it/s]
#
#
#  86%|████████▌ | 1210/1403 [18:57<02:56,  1.10it/s]
#
#
#  86%|████████▋ | 1211/1403 [18:58<03:03,  1.04it/s]
#
#
#  86%|████████▋ | 1212/1403 [18:59<03:21,  1.05s/it]
#
#
#  86%|████████▋ | 1213/1403 [19:00<03:12,  1.01s/it]
#
#
#  87%|████████▋ | 1214/1403 [19:01<03:03,  1.03it/s]
#
#
#  87%|████████▋ | 1215/1403 [19:02<02:55,  1.07it/s]
#
#
#  87%|████████▋ | 1216/1403 [19:03<02:48,  1.11it/s]
#
#
#  87%|████████▋ | 1217/1403 [19:03<02:45,  1.12it/s]
#
#
#  87%|████████▋ | 1218/1403 [19:05<02:55,  1.05it/s]
#
#
#  87%|████████▋ | 1219/1403 [19:05<02:52,  1.07it/s]
#
#
#  87%|████████▋ | 1220/1403 [19:07<03:10,  1.04s/it]
#
#
#  87%|████████▋ | 1221/1403 [19:08<03:23,  1.12s/it]
#
#
#  87%|████████▋ | 1222/1403 [19:09<03:23,  1.12s/it]
#
#
#  87%|████████▋ | 1223/1403 [19:10<03:11,  1.06s/it]
#
#
#  87%|████████▋ | 1224/1403 [19:11<02:54,  1.03it/s]
#
#
#  87%|████████▋ | 1225/1403 [19:12<02:59,  1.01s/it]
#
#
#  87%|████████▋ | 1226/1403 [19:13<03:03,  1.04s/it]
#
#
#  87%|████████▋ | 1227/1403 [19:14<02:54,  1.01it/s]
#
#
#  88%|████████▊ | 1228/1403 [19:15<02:53,  1.01it/s]
#
#
#  88%|████████▊ | 1229/1403 [19:16<02:54,  1.00s/it]
#
#
#  88%|████████▊ | 1230/1403 [19:17<02:40,  1.07it/s]
#
#
#  88%|████████▊ | 1231/1403 [19:18<02:43,  1.05it/s]
#
#
#  88%|████████▊ | 1232/1403 [19:19<02:44,  1.04it/s]
#
#
#  88%|████████▊ | 1233/1403 [19:20<02:42,  1.05it/s]
#
#
#  88%|████████▊ | 1234/1403 [19:20<02:35,  1.09it/s]
#
#
#  88%|████████▊ | 1235/1403 [19:21<02:25,  1.16it/s]
#
#
#  88%|████████▊ | 1236/1403 [19:23<03:18,  1.19s/it]
#
#
#  88%|████████▊ | 1237/1403 [19:24<02:47,  1.01s/it]
#
#
#  88%|████████▊ | 1238/1403 [19:25<02:40,  1.03it/s]
#
#
#  88%|████████▊ | 1239/1403 [19:25<02:28,  1.11it/s]
#
#
#  88%|████████▊ | 1240/1403 [19:26<02:31,  1.07it/s]
#
#
#  88%|████████▊ | 1241/1403 [19:27<02:38,  1.02it/s]
#
#
#  89%|████████▊ | 1242/1403 [19:28<02:40,  1.00it/s]
#
#
#  89%|████████▊ | 1243/1403 [19:29<02:39,  1.00it/s]
#
#
#  89%|████████▊ | 1244/1403 [19:30<02:31,  1.05it/s]
#
#
#  89%|████████▊ | 1245/1403 [19:31<02:29,  1.05it/s]
#
#
#  89%|████████▉ | 1246/1403 [19:32<02:32,  1.03it/s]
#
#
#  89%|████████▉ | 1247/1403 [19:33<02:28,  1.05it/s]
#
#
#  89%|████████▉ | 1248/1403 [19:34<02:19,  1.11it/s]
#
#
#  89%|████████▉ | 1249/1403 [19:35<02:13,  1.15it/s]
#
#
#  89%|████████▉ | 1250/1403 [19:36<02:16,  1.12it/s]
#
#
#  89%|████████▉ | 1251/1403 [19:37<02:17,  1.10it/s]
#
#
#  89%|████████▉ | 1252/1403 [19:38<02:27,  1.03it/s]
#
#
#  89%|████████▉ | 1253/1403 [19:39<02:26,  1.03it/s]
#
#
#  89%|████████▉ | 1254/1403 [19:40<02:26,  1.01it/s]
#
#
#  89%|████████▉ | 1255/1403 [19:41<02:24,  1.03it/s]
#
#
#  90%|████████▉ | 1256/1403 [19:42<02:22,  1.03it/s]
#
#
#  90%|████████▉ | 1257/1403 [19:43<02:17,  1.06it/s]
#
#
#  90%|████████▉ | 1258/1403 [19:44<02:18,  1.05it/s]
#
#
#  90%|████████▉ | 1259/1403 [19:45<02:33,  1.07s/it]
#
#
#  90%|████████▉ | 1260/1403 [19:46<02:23,  1.00s/it]
#
#
#  90%|████████▉ | 1261/1403 [19:46<02:10,  1.09it/s]
#
#
#  90%|████████▉ | 1262/1403 [19:47<02:10,  1.08it/s]
#
#
#  90%|█████████ | 1263/1403 [19:48<02:14,  1.04it/s]
#
#
#  90%|█████████ | 1264/1403 [19:49<02:11,  1.06it/s]
#
#
#  90%|█████████ | 1265/1403 [19:50<02:13,  1.04it/s]
#
#
#  90%|█████████ | 1266/1403 [19:51<02:06,  1.09it/s]
#
#
#  90%|█████████ | 1267/1403 [19:52<02:14,  1.01it/s]
#
#
#  90%|█████████ | 1268/1403 [19:53<02:20,  1.04s/it]
#
#
#  90%|█████████ | 1269/1403 [19:54<02:09,  1.04it/s]
#
#
#  91%|█████████ | 1270/1403 [19:55<01:57,  1.13it/s]
#
#
#  91%|█████████ | 1271/1403 [19:56<01:54,  1.15it/s]
#
#
#  91%|█████████ | 1272/1403 [19:57<01:53,  1.15it/s]
#
#
#  91%|█████████ | 1273/1403 [19:58<02:00,  1.08it/s]
#
#
#  91%|█████████ | 1274/1403 [19:58<01:53,  1.13it/s]
#
#
#  91%|█████████ | 1275/1403 [19:59<01:53,  1.13it/s]
#
#
#  91%|█████████ | 1276/1403 [20:00<01:51,  1.14it/s]
#
#
#  91%|█████████ | 1277/1403 [20:01<01:53,  1.11it/s]
#
#
#  91%|█████████ | 1278/1403 [20:02<01:56,  1.07it/s]
#
#
#  91%|█████████ | 1279/1403 [20:03<01:59,  1.04it/s]
#
#
#  91%|█████████ | 1280/1403 [20:04<02:03,  1.00s/it]
#
#
#  91%|█████████▏| 1281/1403 [20:05<01:59,  1.02it/s]
#
#
#  91%|█████████▏| 1282/1403 [20:06<01:58,  1.02it/s]
#
#
#  91%|█████████▏| 1283/1403 [20:07<01:59,  1.01it/s]
#
#
#  92%|█████████▏| 1284/1403 [20:08<01:55,  1.03it/s]
#
#
#  92%|█████████▏| 1285/1403 [20:09<01:53,  1.04it/s]
#
#
#  92%|█████████▏| 1286/1403 [20:10<01:57,  1.00s/it]
#
#
#  92%|█████████▏| 1287/1403 [20:11<01:59,  1.03s/it]
#
#
#  92%|█████████▏| 1288/1403 [20:12<01:59,  1.04s/it]
#
#
#  92%|█████████▏| 1289/1403 [20:13<02:01,  1.06s/it]
#
#
#  92%|█████████▏| 1290/1403 [20:14<01:47,  1.05it/s]
#
#
#  92%|█████████▏| 1291/1403 [20:15<01:41,  1.10it/s]
#
#
#  92%|█████████▏| 1292/1403 [20:16<01:41,  1.10it/s]
#
#
#  92%|█████████▏| 1293/1403 [20:17<01:46,  1.03it/s]
#
#
#  92%|█████████▏| 1294/1403 [20:18<01:43,  1.06it/s]
#
#
#  92%|█████████▏| 1295/1403 [20:19<01:35,  1.14it/s]
#
#
#  92%|█████████▏| 1296/1403 [20:20<01:37,  1.09it/s]
#
#
#  92%|█████████▏| 1297/1403 [20:21<01:38,  1.08it/s]
#
#
#  93%|█████████▎| 1298/1403 [20:22<01:37,  1.08it/s]
#
#
#  93%|█████████▎| 1299/1403 [20:22<01:19,  1.30it/s]
#
#
#  93%|█████████▎| 1300/1403 [20:23<01:20,  1.27it/s]
#
#
#  93%|█████████▎| 1301/1403 [20:24<01:26,  1.19it/s]
#
#
#  93%|█████████▎| 1302/1403 [20:25<01:24,  1.19it/s]
#
#
#  93%|█████████▎| 1303/1403 [20:25<01:24,  1.19it/s]
#
#
#  93%|█████████▎| 1304/1403 [20:26<01:25,  1.16it/s]
#
#
#  93%|█████████▎| 1305/1403 [20:27<01:23,  1.18it/s]
#
#
#  93%|█████████▎| 1306/1403 [20:28<01:16,  1.27it/s]
#
#
#  93%|█████████▎| 1307/1403 [20:29<01:15,  1.27it/s]
#
#
#  93%|█████████▎| 1308/1403 [20:29<01:15,  1.26it/s]
#
#
#  93%|█████████▎| 1309/1403 [20:30<01:18,  1.20it/s]
#
#
#  93%|█████████▎| 1310/1403 [20:31<01:20,  1.16it/s]
#
#
#  93%|█████████▎| 1311/1403 [20:32<01:22,  1.11it/s]
#
#
#  94%|█████████▎| 1312/1403 [20:33<01:30,  1.00it/s]
#
#
#  94%|█████████▎| 1313/1403 [20:34<01:26,  1.05it/s]
#
#
#  94%|█████████▎| 1314/1403 [20:35<01:30,  1.02s/it]
#
#
#  94%|█████████▎| 1315/1403 [20:36<01:25,  1.03it/s]
#
#
#  94%|█████████▍| 1316/1403 [20:37<01:25,  1.02it/s]
#
#
#  94%|█████████▍| 1317/1403 [20:38<01:20,  1.06it/s]
#
#
#  94%|█████████▍| 1318/1403 [20:39<01:14,  1.14it/s]
#
#
#  94%|█████████▍| 1319/1403 [20:39<01:03,  1.32it/s]
#
#
#  94%|█████████▍| 1320/1403 [20:40<01:06,  1.25it/s]
#
#
#  94%|█████████▍| 1321/1403 [20:41<01:07,  1.21it/s]
#
#
#  94%|█████████▍| 1322/1403 [20:42<01:11,  1.13it/s]
#
#
#  94%|█████████▍| 1323/1403 [20:43<01:14,  1.08it/s]
#
#
#  94%|█████████▍| 1324/1403 [20:44<01:15,  1.04it/s]
#
#
#  94%|█████████▍| 1325/1403 [20:45<01:17,  1.00it/s]
#
#
#  95%|█████████▍| 1326/1403 [20:46<01:13,  1.05it/s]
#
#
#  95%|█████████▍| 1327/1403 [20:47<01:15,  1.01it/s]
#
#
#  95%|█████████▍| 1328/1403 [20:48<01:16,  1.01s/it]
#
#
#  95%|█████████▍| 1329/1403 [20:51<01:59,  1.62s/it]
#
#
#  95%|█████████▍| 1330/1403 [20:52<01:47,  1.47s/it]
#
#
#  95%|█████████▍| 1331/1403 [20:53<01:35,  1.33s/it]
#
#
#  95%|█████████▍| 1332/1403 [20:54<01:22,  1.16s/it]
#
#
#  95%|█████████▌| 1333/1403 [20:56<01:24,  1.21s/it]
#
#
#  95%|█████████▌| 1334/1403 [20:56<01:14,  1.07s/it]
#
#
#  95%|█████████▌| 1335/1403 [20:57<01:10,  1.04s/it]
#
#
#  95%|█████████▌| 1336/1403 [20:58<01:07,  1.00s/it]
#
#
#  95%|█████████▌| 1337/1403 [20:59<01:02,  1.06it/s]
#
#
#  95%|█████████▌| 1338/1403 [21:00<00:58,  1.11it/s]
#
#
#  95%|█████████▌| 1339/1403 [21:01<00:57,  1.12it/s]
#
#
#  96%|█████████▌| 1340/1403 [21:02<00:55,  1.14it/s]
#
#
#  96%|█████████▌| 1341/1403 [21:03<00:59,  1.05it/s]
#
#
#  96%|█████████▌| 1342/1403 [21:04<00:56,  1.08it/s]
#
#
#  96%|█████████▌| 1343/1403 [21:04<00:51,  1.16it/s]
#
#
#  96%|█████████▌| 1344/1403 [21:05<00:51,  1.15it/s]
#
#
#  96%|█████████▌| 1345/1403 [21:06<00:47,  1.23it/s]
#
#
#  96%|█████████▌| 1346/1403 [21:07<00:49,  1.16it/s]
#
#
#  96%|█████████▌| 1347/1403 [21:08<00:49,  1.13it/s]
#
#
#  96%|█████████▌| 1348/1403 [21:09<00:50,  1.10it/s]
#
#
#  96%|█████████▌| 1349/1403 [21:09<00:47,  1.14it/s]
#
#
#  96%|█████████▌| 1350/1403 [21:10<00:48,  1.10it/s]
#
#
#  96%|█████████▋| 1351/1403 [21:11<00:44,  1.18it/s]
#
#
#  96%|█████████▋| 1352/1403 [21:12<00:43,  1.17it/s]
#
#
#  96%|█████████▋| 1353/1403 [21:13<00:40,  1.22it/s]
#
#
#  97%|█████████▋| 1354/1403 [21:14<00:39,  1.23it/s]
#
#
#  97%|█████████▋| 1355/1403 [21:14<00:38,  1.24it/s]
#
#
#  97%|█████████▋| 1356/1403 [21:16<00:45,  1.03it/s]
#
#
#  97%|█████████▋| 1357/1403 [21:17<00:43,  1.05it/s]
#
#
#  97%|█████████▋| 1358/1403 [21:18<00:42,  1.05it/s]
#
#
#  97%|█████████▋| 1359/1403 [21:19<00:42,  1.04it/s]
#
#
#  97%|█████████▋| 1360/1403 [21:19<00:37,  1.14it/s]
#
#
#  97%|█████████▋| 1361/1403 [21:20<00:36,  1.15it/s]
#
#
#  97%|█████████▋| 1362/1403 [21:21<00:35,  1.15it/s]
#
#
#  97%|█████████▋| 1363/1403 [21:22<00:34,  1.17it/s]
#
#
#  97%|█████████▋| 1364/1403 [21:23<00:36,  1.08it/s]
#
#
#  97%|█████████▋| 1365/1403 [21:24<00:38,  1.02s/it]
#
#
#  97%|█████████▋| 1366/1403 [21:25<00:37,  1.01s/it]
#
#
#  97%|█████████▋| 1367/1403 [21:26<00:36,  1.01s/it]
#
#
#  98%|█████████▊| 1368/1403 [21:27<00:35,  1.03s/it]
#
#
#  98%|█████████▊| 1369/1403 [21:28<00:35,  1.04s/it]
#
#
#  98%|█████████▊| 1370/1403 [21:29<00:32,  1.02it/s]
#
#
#  98%|█████████▊| 1371/1403 [21:30<00:31,  1.02it/s]
#
#
#  98%|█████████▊| 1372/1403 [21:31<00:29,  1.04it/s]
#
#
#  98%|█████████▊| 1373/1403 [21:32<00:28,  1.07it/s]
#
#
#  98%|█████████▊| 1374/1403 [21:33<00:25,  1.15it/s]
#
#
#  98%|█████████▊| 1375/1403 [21:34<00:25,  1.09it/s]
#
#
#  98%|█████████▊| 1376/1403 [21:35<00:24,  1.09it/s]
#
#
#  98%|█████████▊| 1377/1403 [21:35<00:23,  1.09it/s]
#
#
#  98%|█████████▊| 1378/1403 [21:36<00:23,  1.05it/s]
#
#
#  98%|█████████▊| 1379/1403 [21:37<00:22,  1.04it/s]
#
#
#  98%|█████████▊| 1380/1403 [21:38<00:20,  1.11it/s]
#
#
#  98%|█████████▊| 1381/1403 [21:39<00:18,  1.16it/s]
#
#
#  99%|█████████▊| 1382/1403 [21:40<00:19,  1.08it/s]
#
#
#  99%|█████████▊| 1383/1403 [21:41<00:18,  1.09it/s]
#
#
#  99%|█████████▊| 1384/1403 [21:42<00:16,  1.14it/s]
#
#
#  99%|█████████▊| 1385/1403 [21:43<00:15,  1.16it/s]
#
#
#  99%|█████████▉| 1386/1403 [21:44<00:15,  1.13it/s]
#
#
#  99%|█████████▉| 1387/1403 [21:44<00:14,  1.14it/s]
#
#
#  99%|█████████▉| 1388/1403 [21:45<00:13,  1.09it/s]
#
#
#  99%|█████████▉| 1389/1403 [21:46<00:13,  1.05it/s]
#
#
#  99%|█████████▉| 1390/1403 [21:47<00:12,  1.02it/s]
#
#
#  99%|█████████▉| 1391/1403 [21:48<00:10,  1.10it/s]
#
#
#  99%|█████████▉| 1392/1403 [21:49<00:10,  1.07it/s]
#
#
#  99%|█████████▉| 1393/1403 [21:50<00:09,  1.08it/s]
#
#
#  99%|█████████▉| 1394/1403 [21:51<00:07,  1.15it/s]
#
#
#  99%|█████████▉| 1395/1403 [21:52<00:07,  1.08it/s]
#
#
# 100%|█████████▉| 1396/1403 [21:53<00:06,  1.05it/s]
#
#
# 100%|█████████▉| 1397/1403 [21:54<00:05,  1.06it/s]
#
#
# 100%|█████████▉| 1398/1403 [21:55<00:04,  1.11it/s]
#
#
# 100%|█████████▉| 1399/1403 [21:56<00:03,  1.06it/s]
#
#
# 100%|█████████▉| 1400/1403 [21:57<00:02,  1.08it/s]
#
#
# 100%|█████████▉| 1401/1403 [21:58<00:02,  1.01s/it]
#
#
# 100%|█████████▉| 1402/1403 [21:59<00:00,  1.01it/s]
#
#
# 100%|██████████| 1403/1403 [22:00<00:00,  1.06it/s]

# %% [markdown]
# # PSPNet from Scratch

# %%
# Initialize wandb with your project name
run = wandb.init(project='my-keras-integration',
                 config={  # and include hyperparameters and metadata
                     "learning_rate": 0.005,
                     "epochs": 50,
                     "batch_size": 16,
                     "loss_function": "sparse_categorical_crossentropy",
                     "architecture": "PSPNET",
                     "dataset": "idd-lite"
                 })
config = wandb.config  # We'll use this to configure our experiment

# Initialize model like you usually do.
#tf.keras.backend.clear_session()
#model = Model()
#model.summary()

# Compile model like you usually do.
# Notice that we use config, so our metadata matches what gets executed
#optimizer = tf.keras.optimizers.Adam(config.learning_rate) 
#model.compile(optimizer, config.loss_function, metrics=['acc'])
# Out:
# wandb: Currently logged in as: github2020 (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.28<br/>
#                 Syncing run <strong style="color:#cdcd00">robust-serenity-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/github2020/my-keras-integration" target="_blank">https://wandb.ai/github2020/my-keras-integration</a><br/>
#                 Run page: <a href="https://wandb.ai/github2020/my-keras-integration/runs/1ebwo8o5" target="_blank">https://wandb.ai/github2020/my-keras-integration/runs/1ebwo8o5</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210502_064406-1ebwo8o5</code><br/><br/>

# %%
# A class to get the basic convolution block 
# convolution_layer -> batch_normalization -> activation
class BasicConvolutionBlock(tf.keras.Model):
    
    def __init__(self, filter_size, kernel_size, dilation_rate, alpha, block_number, initializer='he_normal'):
        super(BasicConvolutionBlock, self).__init__()
        self.block_number = block_number
        self.convolution_layer = Convolution2D(filter_size, kernel_size =  kernel_size, 
                                               dilation_rate = dilation_rate, padding = 'same',
                                               kernel_initializer = initializer)
        self.batch_normalization = BatchNormalization()
        self.activation = LeakyReLU(alpha = alpha)
        
    def call(self, inputs):
        conv_output = self.convolution_layer(inputs)
        norm_output = self.batch_normalization(conv_output)
        if(self.block_number >= 3):
            return norm_output
        activation_output = self.activation(norm_output)  
        return activation_output

# %%
# A Building Block of Residual Network
class ConvolutionBlock(tf.keras.Model):
    
    def __init__(self, filters, initializer='he_normal'):     
        super(ConvolutionBlock, self).__init__()
        self.filters = filters
        self.basic_convolution_1 = BasicConvolutionBlock(self.filters[0], (1,1), (1,1), 0.2, 1)
        self.basic_convolution_2 = BasicConvolutionBlock(self.filters[1], (3,3), (2,2), 0.2, 2)
        self.basic_convolution_3 = BasicConvolutionBlock(self.filters[2], (1,1), (1,1), None, 3)
        self.skip_convolution = BasicConvolutionBlock(self.filters[2], (3,3), (1,1), None, 4)
        # Last Block
        self.add_layer = Add()
        self.relu_activation = ReLU()
     
    def call(self, inputs):
        skip_input = inputs
        output_conv_1 = self.basic_convolution_1(inputs)
        output_conv_2 = self.basic_convolution_2(output_conv_1)
        output_conv_3 = self.basic_convolution_3(output_conv_2)
        output_skip_conv = self.skip_convolution(skip_input)
        # Last Block
        add_output = self.add_layer([output_conv_3,output_skip_conv])
        output = self.relu_activation(add_output)
        return output

# %%
# Encoder block for PSPNet Net
class EncoderBlock(tf.keras.Model):
    
    def __init__(self, filters):
        super(EncoderBlock, self).__init__()
        self.filters = filters
        self.convolution_block_1 = ConvolutionBlock(self.filters[0])
        self.convolution_block_2 = ConvolutionBlock(self.filters[1])
        self.convolution_block_3 = ConvolutionBlock(self.filters[2])
        self.convolution_block_4 = ConvolutionBlock(self.filters[3])
        
    def call(self, inputs):     
        output_block_1 = self.convolution_block_1(inputs)
        output_block_2 = self.convolution_block_2(output_block_1)
        output_block_3 = self.convolution_block_3(output_block_2) 
        output_block_4 = self.convolution_block_4(output_block_3)
        return output_block_4

# %%
# This class returns the pyramid feature map for Pyramid Pooling module
# Pooling -> Convolution -> UpSampling
class PyramidFeatureMap(tf.keras.Model):
    
    def __init__(self, block, filter_size, unsampling_size, pool_size, interpolation='bilinear'):
        super(PyramidFeatureMap, self).__init__()
        self.block = block
        self.convolution_layer = Convolution2D(filter_size, kernel_size = (1,1))
        self.upsampling_layer = UpSampling2D(unsampling_size, interpolation = interpolation)
        self.average_pooling = AveragePooling2D(pool_size)
        self.global_average_pooling = GlobalAveragePooling2D()
        
    def call(self,inputs):
        if(self.block=='red'):
            pool_output = self.global_average_pooling(inputs)
            pool_output = Reshape((1,1,512))(pool_output)
        else:
            pool_output = self.average_pooling(inputs)
        conv_output = self.convolution_layer(pool_output)
        upsampling_output = self.upsampling_layer(conv_output)
        return upsampling_output

# %%
# This class builds the Pyramid Pooling Module
# It builds the 4 feature maps and then concatenates all of them with the input
class PyramidPoolingModule(tf.keras.Model):
    
    def __init__(self):
        super(PyramidPoolingModule, self).__init__()
        self.block_red = PyramidFeatureMap('red', 64, (128,128), (1,1))
        self.block_yellow = PyramidFeatureMap('yellow', 64, 2, (2,2))
        self.block_blue = PyramidFeatureMap('blue', 64, 4, (4,4))
        self.block_green = PyramidFeatureMap('green', 64, 8, (8,8))
        
    def call(self,inputs):
        red_output = self.block_red(inputs)
        yellow_output = self.block_yellow(inputs)
        blue_output = self.block_blue(inputs)
        green_output = self.block_green(inputs)
        merged = concatenate([inputs, red_output, yellow_output, blue_output, green_output])
        return merged

# %%
# This block is for the last stage
# It gets the output of Pyramid Pooling Module and then performs convolution operation
# Pyramid Pooling -> Convolution -> Batch Normalization -> Softmax activation
class DecoderBlock(tf.keras.Model):
    
    def __init__(self, num_classes):
        super(DecoderBlock, self).__init__()
        self.pyramid_pooling_module = PyramidPoolingModule()
        self.convolution_layer = Convolution2D(num_classes, kernel_size = (3,3), padding = 'same')
        self.batch_norm_layer = BatchNormalization()
        self.activation = Activation('softmax')
    
    def call(self, inputs):
        merged = self.pyramid_pooling_module(inputs)
        conv_output = self.convolution_layer(merged)
        norm_output = self.batch_norm_layer(conv_output)
        output = self.activation(norm_output)
        return output

# %%
#This final class for the Model
class PSPNetModel(tf.keras.Model):
    
    def __init__(self, num_classes):
        super(PSPNetModel, self).__init__()
        self.encoder = EncoderBlock([[32,32,64],[64,64,128],[128,128,256],[256,256,512]])
        self.decoder = DecoderBlock(num_classes)
        
    def call(self, inputs):
        encoder_output = self.encoder(inputs)
        final_output = self.decoder(encoder_output)
        return final_output

# %%
from tensorflow.keras.layers import *
# SegmentationModel object
model = PSPNetModel(N_CLASSES)

# %%
# Defining a loss object and an optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()
ckpt = tf.train.Checkpoint(step=tf.Variable(1), optimizer=optimizer, net=model)
manager = tf.train.CheckpointManager(ckpt, 'tf_ckpts/', max_to_keep=3)

# %%
# Define the metrics
train_loss = tf.keras.metrics.Mean('train_loss', dtype=tf.float32)
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy('train_accuracy')
test_loss = tf.keras.metrics.Mean('test_loss', dtype=tf.float32)
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy('test_accuracy')

# %%
# Reference -> https://github.com/junhoning/machine_learning_tutorial/blob/b20b8a10438ec3e62f08f920744cc8ea854cde91/Visualization%20%26%20TensorBoard/%5BTensorBoard%5D%20Semantic%20Segmentation.ipynb

@tf.function
def train_step(model, optimizer, x_train, y_train):
    with tf.GradientTape() as tape:
        predictions = model(x_train, training=True)
        loss = loss_object(y_train, predictions)
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    train_loss(loss)
    train_accuracy(y_train, predictions)
    
def train_and_checkpoint(model, manager, dataset, epoch):
    ckpt.restore(manager.latest_checkpoint)
    if manager.latest_checkpoint:
        print("Restored from {}".format(manager.latest_checkpoint))
    else:
        print("Initializing from scratch.")
    for (x_train, y_train) in dataset['train'].take(math.ceil(1403/8)):
        train_step(model, optimizer, x_train, y_train)
    ckpt.step.assign_add(1)
    save_path = manager.save()
    print("Saved checkpoint for epoch {}: {}".format(epoch, save_path))
    
@tf.function
def test_step(model, x_test, y_test):
    predictions = model(x_test)
    loss = loss_object(y_test, predictions)
    test_loss(loss)
    test_accuracy(y_test, predictions)
    return predictions

# %%
train_log_dir = 'logs/gradient_tape/train'
test_log_dir = 'logs/gradient_tape/test'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
test_summary_writer = tf.summary.create_file_writer(test_log_dir)

# %%
# This variable will help to save the best model if its performance increases after an epoch   
highest_accuracy = 0

# Training the model for 40 epochs
for epoch in range(50):

    print("Epoch ",epoch+1)
    
    # Getting the current time before starting the training
    # This will help to keep track of how much time an epoch took
    start = time.time()
    
    train_and_checkpoint(model, manager, dataset, epoch+1)
    
    # Saving the train loss and train accuracy metric for TensorBoard visualization
    with train_summary_writer.as_default():
        tf.summary.scalar('loss', train_loss.result(), step=ckpt.step.numpy())
        tf.summary.scalar('accuracy', train_accuracy.result(), step=ckpt.step.numpy())
    
    # Validation phase
    for (x_test, y_test) in dataset['val'].take(math.ceil(204/8)):
        pred = test_step(model, x_test, y_test)
    
    # Saving the validation loss and validation accuracy metric for Tensorboard visualization
    with test_summary_writer.as_default():
        tf.summary.scalar('loss', test_loss.result(), step=ckpt.step.numpy())
        tf.summary.scalar('accuracy', test_accuracy.result(), step=ckpt.step.numpy())
    
    # Calculating the time it took for the entire epoch to run
    print("Time taken ",time.time()-start)
    
    # Printing the metrics for the epoch
    template = 'Epoch {}, Loss: {:.3f}, Accuracy: {:.3f}, Val Loss: {:.3f}, Val Accuracy: {:.3f}'
    print (template.format(epoch+1,
                            train_loss.result(), 
                            train_accuracy.result()*100,
                            test_loss.result(), 
                            test_accuracy.result()*100))
    
    # If accuracy has increased in this epoch, updating the highest accuracy and saving the model
    if(test_accuracy.result().numpy()*100>highest_accuracy):
        print("Validation accuracy increased from {:.3f} to {:.3f}. Saving model weights.".format(highest_accuracy,test_accuracy.result().numpy()*100))
        highest_accuracy = test_accuracy.result().numpy()*100
        model.save_weights('pspnet_weights-epoch-{}.hdf5'.format(epoch+1))

    print('_'*80)

    # Reset metrics after every epoch
    train_loss.reset_states()
    test_loss.reset_states()
    train_accuracy.reset_states()
    test_accuracy.reset_states()
# Out:
# Epoch  1
# Initializing from scratch.
# Saved checkpoint for epoch 1: tf_ckpts/ckpt-1
# Time taken  1005.167932510376
# Epoch 1, Loss: 1.093, Accuracy: 69.633, Val Loss: 1.468, Val Accuracy: 49.131
# Validation accuracy increased from 0.000 to 49.131. Saving model weights.
# ________________________________________________________________________________
# Epoch  2
# Restored from tf_ckpts/ckpt-1
# Saved checkpoint for epoch 2: tf_ckpts/ckpt-2
# Time taken  53.682374000549316
# Epoch 2, Loss: 0.859, Accuracy: 74.772, Val Loss: 0.933, Val Accuracy: 71.400
# Validation accuracy increased from 49.131 to 71.400. Saving model weights.
# ________________________________________________________________________________
# Epoch  3
# Restored from tf_ckpts/ckpt-2
# Saved checkpoint for epoch 3: tf_ckpts/ckpt-3
# Time taken  53.810667991638184
# Epoch 3, Loss: 0.735, Accuracy: 76.871, Val Loss: 0.747, Val Accuracy: 74.416
# Validation accuracy increased from 71.400 to 74.416. Saving model weights.
# ________________________________________________________________________________
# Epoch  4
# Restored from tf_ckpts/ckpt-3
# Saved checkpoint for epoch 4: tf_ckpts/ckpt-4
# Time taken  53.76520276069641
# Epoch 4, Loss: 0.668, Accuracy: 77.719, Val Loss: 0.726, Val Accuracy: 74.090
# ________________________________________________________________________________
# Epoch  5
# Restored from tf_ckpts/ckpt-4
# Saved checkpoint for epoch 5: tf_ckpts/ckpt-5
# Time taken  53.79494786262512
# Epoch 5, Loss: 0.615, Accuracy: 78.547, Val Loss: 0.641, Val Accuracy: 77.240
# Validation accuracy increased from 74.416 to 77.240. Saving model weights.
# ________________________________________________________________________________
# Epoch  6
# Restored from tf_ckpts/ckpt-5
# Saved checkpoint for epoch 6: tf_ckpts/ckpt-6
# Time taken  53.92703557014465
# Epoch 6, Loss: 0.579, Accuracy: 79.180, Val Loss: 0.651, Val Accuracy: 76.519
# ________________________________________________________________________________
# Epoch  7
# Restored from tf_ckpts/ckpt-6
# Saved checkpoint for epoch 7: tf_ckpts/ckpt-7
# Time taken  53.89549946784973
# Epoch 7, Loss: 0.553, Accuracy: 79.592, Val Loss: 0.633, Val Accuracy: 75.915
# ________________________________________________________________________________
# Epoch  8
# Restored from tf_ckpts/ckpt-7
# Saved checkpoint for epoch 8: tf_ckpts/ckpt-8
# Time taken  53.817436933517456
# Epoch 8, Loss: 0.528, Accuracy: 80.118, Val Loss: 0.586, Val Accuracy: 77.645
# Validation accuracy increased from 77.240 to 77.645. Saving model weights.
# ________________________________________________________________________________
# Epoch  9
# Restored from tf_ckpts/ckpt-8
# Saved checkpoint for epoch 9: tf_ckpts/ckpt-9
# Time taken  53.816383838653564
# Epoch 9, Loss: 0.506, Accuracy: 80.585, Val Loss: 0.547, Val Accuracy: 77.728
# Validation accuracy increased from 77.645 to 77.728. Saving model weights.
# ________________________________________________________________________________
# Epoch  10
# Restored from tf_ckpts/ckpt-9
# Saved checkpoint for epoch 10: tf_ckpts/ckpt-10
# Time taken  53.77402591705322
# Epoch 10, Loss: 0.491, Accuracy: 80.936, Val Loss: 0.600, Val Accuracy: 76.336
# ________________________________________________________________________________
# Epoch  11
# Restored from tf_ckpts/ckpt-10
# Saved checkpoint for epoch 11: tf_ckpts/ckpt-11
# Time taken  53.90226364135742
# Epoch 11, Loss: 0.478, Accuracy: 81.196, Val Loss: 0.593, Val Accuracy: 77.972
# Validation accuracy increased from 77.728 to 77.972. Saving model weights.
# ________________________________________________________________________________
# Epoch  12
# Restored from tf_ckpts/ckpt-11
# Saved checkpoint for epoch 12: tf_ckpts/ckpt-12
# Time taken  53.84124946594238
# Epoch 12, Loss: 0.462, Accuracy: 81.639, Val Loss: 0.587, Val Accuracy: 75.453
# ________________________________________________________________________________
# Epoch  13
# Restored from tf_ckpts/ckpt-12
# Saved checkpoint for epoch 13: tf_ckpts/ckpt-13
# Time taken  53.84312844276428
# Epoch 13, Loss: 0.452, Accuracy: 81.910, Val Loss: 0.543, Val Accuracy: 77.882
# ________________________________________________________________________________
# Epoch  14
# Restored from tf_ckpts/ckpt-13
# Saved checkpoint for epoch 14: tf_ckpts/ckpt-14
# Time taken  53.833924293518066
# Epoch 14, Loss: 0.440, Accuracy: 82.247, Val Loss: 0.573, Val Accuracy: 77.737
# ________________________________________________________________________________
# Epoch  15
# Restored from tf_ckpts/ckpt-14
# Saved checkpoint for epoch 15: tf_ckpts/ckpt-15
# Time taken  53.83728384971619
# Epoch 15, Loss: 0.428, Accuracy: 82.604, Val Loss: 0.557, Val Accuracy: 78.036
# Validation accuracy increased from 77.972 to 78.036. Saving model weights.
# ________________________________________________________________________________
# Epoch  16
# Restored from tf_ckpts/ckpt-15
# Saved checkpoint for epoch 16: tf_ckpts/ckpt-16
# Time taken  53.75545954704285
# Epoch 16, Loss: 0.420, Accuracy: 82.805, Val Loss: 0.535, Val Accuracy: 78.884
# Validation accuracy increased from 78.036 to 78.884. Saving model weights.
# ________________________________________________________________________________
# Epoch  17
# Restored from tf_ckpts/ckpt-16
# Saved checkpoint for epoch 17: tf_ckpts/ckpt-17
# Time taken  53.985382080078125
# Epoch 17, Loss: 0.411, Accuracy: 83.095, Val Loss: 0.527, Val Accuracy: 79.249
# Validation accuracy increased from 78.884 to 79.249. Saving model weights.
# ________________________________________________________________________________
# Epoch  18
# Restored from tf_ckpts/ckpt-17
# Saved checkpoint for epoch 18: tf_ckpts/ckpt-18
# Time taken  53.8040611743927
# Epoch 18, Loss: 0.404, Accuracy: 83.285, Val Loss: 0.600, Val Accuracy: 77.317
# ________________________________________________________________________________
# Epoch  19
# Restored from tf_ckpts/ckpt-18
# Saved checkpoint for epoch 19: tf_ckpts/ckpt-19
# Time taken  53.84971570968628
# Epoch 19, Loss: 0.397, Accuracy: 83.499, Val Loss: 0.498, Val Accuracy: 79.443
# Validation accuracy increased from 79.249 to 79.443. Saving model weights.
# ________________________________________________________________________________
# Epoch  20
# Restored from tf_ckpts/ckpt-19
# Saved checkpoint for epoch 20: tf_ckpts/ckpt-20
# Time taken  53.912665605545044
# Epoch 20, Loss: 0.387, Accuracy: 83.808, Val Loss: 0.520, Val Accuracy: 78.925
# ________________________________________________________________________________
# Epoch  21
# Restored from tf_ckpts/ckpt-20
# Saved checkpoint for epoch 21: tf_ckpts/ckpt-21
# Time taken  53.8768892288208
# Epoch 21, Loss: 0.380, Accuracy: 84.073, Val Loss: 0.526, Val Accuracy: 78.551
# ________________________________________________________________________________
# Epoch  22
# Restored from tf_ckpts/ckpt-21
# Saved checkpoint for epoch 22: tf_ckpts/ckpt-22
# Time taken  53.84022283554077
# Epoch 22, Loss: 0.376, Accuracy: 84.186, Val Loss: 0.494, Val Accuracy: 79.642
# Validation accuracy increased from 79.443 to 79.642. Saving model weights.
# ________________________________________________________________________________
# Epoch  23
# Restored from tf_ckpts/ckpt-22
# Saved checkpoint for epoch 23: tf_ckpts/ckpt-23
# Time taken  53.81229591369629
# Epoch 23, Loss: 0.366, Accuracy: 84.539, Val Loss: 0.536, Val Accuracy: 78.488
# ________________________________________________________________________________
# Epoch  24
# Restored from tf_ckpts/ckpt-23
# Saved checkpoint for epoch 24: tf_ckpts/ckpt-24
# Time taken  54.086074352264404
# Epoch 24, Loss: 0.362, Accuracy: 84.637, Val Loss: 0.479, Val Accuracy: 80.504
# Validation accuracy increased from 79.642 to 80.504. Saving model weights.
# ________________________________________________________________________________
# Epoch  25
# Restored from tf_ckpts/ckpt-24
# Saved checkpoint for epoch 25: tf_ckpts/ckpt-25
# Time taken  53.785714864730835
# Epoch 25, Loss: 0.356, Accuracy: 84.860, Val Loss: 0.503, Val Accuracy: 80.254
# ________________________________________________________________________________
# Epoch  26
# Restored from tf_ckpts/ckpt-25
# Saved checkpoint for epoch 26: tf_ckpts/ckpt-26
# Time taken  53.80301356315613
# Epoch 26, Loss: 0.349, Accuracy: 85.088, Val Loss: 0.518, Val Accuracy: 78.308
# ________________________________________________________________________________
# Epoch  27
# Restored from tf_ckpts/ckpt-26
# Saved checkpoint for epoch 27: tf_ckpts/ckpt-27
# Time taken  54.01676964759827
# Epoch 27, Loss: 0.342, Accuracy: 85.383, Val Loss: 0.513, Val Accuracy: 79.322
# ________________________________________________________________________________
# Epoch  28
# Restored from tf_ckpts/ckpt-27
# Saved checkpoint for epoch 28: tf_ckpts/ckpt-28
# Time taken  53.99693274497986
# Epoch 28, Loss: 0.336, Accuracy: 85.569, Val Loss: 0.503, Val Accuracy: 79.681
# ________________________________________________________________________________
# Epoch  29
# Restored from tf_ckpts/ckpt-28
# Saved checkpoint for epoch 29: tf_ckpts/ckpt-29
# Time taken  53.819976568222046
# Epoch 29, Loss: 0.332, Accuracy: 85.686, Val Loss: 0.479, Val Accuracy: 80.182
# ________________________________________________________________________________
# Epoch  30
# Restored from tf_ckpts/ckpt-29
# Saved checkpoint for epoch 30: tf_ckpts/ckpt-30
# Time taken  53.93294167518616
# Epoch 30, Loss: 0.322, Accuracy: 86.081, Val Loss: 0.489, Val Accuracy: 80.538
# Validation accuracy increased from 80.504 to 80.538. Saving model weights.
# ________________________________________________________________________________
# Epoch  31
# Restored from tf_ckpts/ckpt-30
# Saved checkpoint for epoch 31: tf_ckpts/ckpt-31
# Time taken  53.78158092498779
# Epoch 31, Loss: 0.321, Accuracy: 86.094, Val Loss: 0.490, Val Accuracy: 80.138
# ________________________________________________________________________________
# Epoch  32
# Restored from tf_ckpts/ckpt-31
# Saved checkpoint for epoch 32: tf_ckpts/ckpt-32
# Time taken  53.84576654434204
# Epoch 32, Loss: 0.311, Accuracy: 86.492, Val Loss: 0.478, Val Accuracy: 80.286
# ________________________________________________________________________________
# Epoch  33
# Restored from tf_ckpts/ckpt-32
# Saved checkpoint for epoch 33: tf_ckpts/ckpt-33
# Time taken  53.818657875061035
# Epoch 33, Loss: 0.306, Accuracy: 86.674, Val Loss: 0.475, Val Accuracy: 80.289
# ________________________________________________________________________________
# Epoch  34
# Restored from tf_ckpts/ckpt-33
# Saved checkpoint for epoch 34: tf_ckpts/ckpt-34
# Time taken  53.820995569229126
# Epoch 34, Loss: 0.301, Accuracy: 86.872, Val Loss: 0.525, Val Accuracy: 80.362
# ________________________________________________________________________________
# Epoch  35
# Restored from tf_ckpts/ckpt-34
# Saved checkpoint for epoch 35: tf_ckpts/ckpt-35
# Time taken  53.863407135009766
# Epoch 35, Loss: 0.293, Accuracy: 87.144, Val Loss: 0.466, Val Accuracy: 80.647
# Validation accuracy increased from 80.538 to 80.647. Saving model weights.
# ________________________________________________________________________________
# Epoch  36
# Restored from tf_ckpts/ckpt-35
# Saved checkpoint for epoch 36: tf_ckpts/ckpt-36
# Time taken  53.89192318916321
# Epoch 36, Loss: 0.293, Accuracy: 87.157, Val Loss: 0.503, Val Accuracy: 80.303
# ________________________________________________________________________________
# Epoch  37
# Restored from tf_ckpts/ckpt-36
# Saved checkpoint for epoch 37: tf_ckpts/ckpt-37
# Time taken  53.85819458961487
# Epoch 37, Loss: 0.282, Accuracy: 87.579, Val Loss: 0.526, Val Accuracy: 80.038
# ________________________________________________________________________________
# Epoch  38
# Restored from tf_ckpts/ckpt-37
# Saved checkpoint for epoch 38: tf_ckpts/ckpt-38
# Time taken  53.84472107887268
# Epoch 38, Loss: 0.281, Accuracy: 87.622, Val Loss: 0.517, Val Accuracy: 80.179
# ________________________________________________________________________________
# Epoch  39
# Restored from tf_ckpts/ckpt-38
# Saved checkpoint for epoch 39: tf_ckpts/ckpt-39
# Time taken  53.83328175544739
# Epoch 39, Loss: 0.271, Accuracy: 88.001, Val Loss: 0.529, Val Accuracy: 79.370
# ________________________________________________________________________________
# Epoch  40
# Restored from tf_ckpts/ckpt-39
# Saved checkpoint for epoch 40: tf_ckpts/ckpt-40
# Time taken  53.82341456413269
# Epoch 40, Loss: 0.267, Accuracy: 88.133, Val Loss: 0.486, Val Accuracy: 80.447
# ________________________________________________________________________________
# Epoch  41
# Restored from tf_ckpts/ckpt-40
# Saved checkpoint for epoch 41: tf_ckpts/ckpt-41
# Time taken  54.028921127319336
# Epoch 41, Loss: 0.266, Accuracy: 88.195, Val Loss: 0.512, Val Accuracy: 80.256
# ________________________________________________________________________________
# Epoch  42
# Restored from tf_ckpts/ckpt-41
# Saved checkpoint for epoch 42: tf_ckpts/ckpt-42
# Time taken  53.83165264129639
# Epoch 42, Loss: 0.265, Accuracy: 88.213, Val Loss: 0.511, Val Accuracy: 79.858
# ________________________________________________________________________________
# Epoch  43
# Restored from tf_ckpts/ckpt-42
# Saved checkpoint for epoch 43: tf_ckpts/ckpt-43
# Time taken  53.82704949378967
# Epoch 43, Loss: 0.261, Accuracy: 88.388, Val Loss: 0.532, Val Accuracy: 80.041
# ________________________________________________________________________________
# Epoch  44
# Restored from tf_ckpts/ckpt-43
# Saved checkpoint for epoch 44: tf_ckpts/ckpt-44
# Time taken  53.8248291015625
# Epoch 44, Loss: 0.248, Accuracy: 88.875, Val Loss: 0.504, Val Accuracy: 80.663
# Validation accuracy increased from 80.647 to 80.663. Saving model weights.
# ________________________________________________________________________________
# Epoch  45
# Restored from tf_ckpts/ckpt-44
# Saved checkpoint for epoch 45: tf_ckpts/ckpt-45
# Time taken  53.784055948257446
# Epoch 45, Loss: 0.242, Accuracy: 89.094, Val Loss: 0.635, Val Accuracy: 78.831
# ________________________________________________________________________________
# Epoch  46
# Restored from tf_ckpts/ckpt-45
# Saved checkpoint for epoch 46: tf_ckpts/ckpt-46
# Time taken  53.94414782524109
# Epoch 46, Loss: 0.238, Accuracy: 89.253, Val Loss: 0.516, Val Accuracy: 80.874
# Validation accuracy increased from 80.663 to 80.874. Saving model weights.
# ________________________________________________________________________________
# Epoch  47
# Restored from tf_ckpts/ckpt-46
# Saved checkpoint for epoch 47: tf_ckpts/ckpt-47
# Time taken  53.86498522758484
# Epoch 47, Loss: 0.236, Accuracy: 89.272, Val Loss: 0.550, Val Accuracy: 79.949
# ________________________________________________________________________________
# Epoch  48
# Restored from tf_ckpts/ckpt-47
# Saved checkpoint for epoch 48: tf_ckpts/ckpt-48
# Time taken  53.840487003326416
# Epoch 48, Loss: 0.234, Accuracy: 89.370, Val Loss: 0.568, Val Accuracy: 78.247
# ________________________________________________________________________________
# Epoch  49
# Restored from tf_ckpts/ckpt-48
# Saved checkpoint for epoch 49: tf_ckpts/ckpt-49
# Time taken  53.82972192764282
# Epoch 49, Loss: 0.230, Accuracy: 89.491, Val Loss: 0.511, Val Accuracy: 80.412
# ________________________________________________________________________________
# Epoch  50
# Restored from tf_ckpts/ckpt-49
# Saved checkpoint for epoch 50: tf_ckpts/ckpt-50
# Time taken  53.821423053741455
# Epoch 50, Loss: 0.221, Accuracy: 89.824, Val Loss: 0.534, Val Accuracy: 80.292
# ________________________________________________________________________________

# %%
from IPython.core.display import Image, display
display(Image('From scratch.png'))

# %%
# Loading the weights of the best model
model.load_weights('pspnet_weights-epoch-40.hdf5')

# %%
def predict(model,image_path):
    """
    This function will take the model which is going to be used to predict the image and the image path of 
    the input image as inputs and predict the mask
    It returns the true mask and predicted mask
    """
    # Getting the datapoint
    # This function will load the image and its annotation (mask) and return a dictionary.
    datapoint = parse_image(image_path)
    # Normalizing the resizing the datapoint
    input_image,image_mask = load_image_test(datapoint)
    # As the model takes input with 4 dimensions (batch_size, rows, columns, channels),
    # and the shape of the input image is (rows, columns, channels)
    # we will expand the first dimension so we will get the shape as  (1, rows, columns, channels)
    img = tf.expand_dims(input_image, 0)
    # Predicting the image by passing it to the model
    prediction = model(img)
    # The model will predict 8 outputs for each pixel
    # We have to get the maximum value out of it
    prediction = tf.argmax(prediction, axis=-1)
    prediction = tf.squeeze(prediction, axis = 0)
    pred_mask = tf.expand_dims(prediction, axis=-1)
    # Displaying the input image, true mask, predicted mask
    #display_sample([input_image, image_mask, pred_mask])
    return image_mask, pred_mask

# %%
# Reference -> https://github.com/saisandeepNSS/IDD_SemanticSegmentation

def IoU(y_i,y_pred):
    # This function calculates the mean Intersection over Union
    # Mean IoU = TP/(FN + TP + FP)
    # This list will save the IoU of all the classes
    IoUs = []
    # Defining the number of classes which the model has predicted
    n_classes = 8
    for c in range(n_classes):
        # Calculating the True Positives
        TP = np.sum((y_i == c)&(y_pred==c))
        # Calculating the False Positives
        FP = np.sum((y_i != c)&(y_pred==c))
        # Calculating the False Negatives
        FN = np.sum((y_i == c)&(y_pred!= c))
        # Calculating the IoU for the particular class
        IoU = TP/float(TP + FP + FN)
        # Printing the outputs
        # Uncomment the print statement below when you want to analyze the results for each class
        #print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        # Appending the IoU to the list as it mean needs to be calculated later
        if(math.isnan(IoU)):
            IoUs.append(0)
            continue
        IoUs.append(IoU)
    # Calculating the mean
    mIoU = np.mean(IoUs)
    #print("_________________")
    #print("Mean IoU: {:4.3f}".format(mIoU))
    return mIoU

# %% [markdown]
# ### Validation mIoU for PSPNet from scratch

# %%
img_val = dataset_path + 'leftImg8bit/val/'
val_paths = glob(img_val+'*/*_image.jpg')

# %%
mIoU = []
for path in val_paths:
    true_mask, pred_mask = predict(model,path)
    mIoU.append(IoU(true_mask, pred_mask))

# %%
print("Validation mIoU = ",sum(mIoU)/len(mIoU))
# Out:
# Validation mIoU =  0.43782475543376675

# %% [markdown]
# # PSPNet with a pretrained Encoder

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
# This class returns the pyramid feature map for Pyramid Pooling module
# Pooling -> Convolution -> UpSampling
class PyramidFeatureMap(tf.keras.Model):
    
    def __init__(self, block, filter_size, unsampling_size, pool_size, interpolation='bilinear'):
        super(PyramidFeatureMap, self).__init__()
        self.block = block
        self.convolution_layer = Convolution2D(filter_size, kernel_size = (1,1))
        self.upsampling_layer = UpSampling2D(unsampling_size, interpolation = interpolation)
        self.average_pooling = AveragePooling2D(pool_size)
        self.global_average_pooling = GlobalAveragePooling2D()
        
    def call(self,inputs):
        if(self.block=='red'):
            pool_output = self.global_average_pooling(inputs)
            pool_output = Reshape((1,1,2048))(pool_output)
        else:
            pool_output = self.average_pooling(inputs)
        conv_output = self.convolution_layer(pool_output)
        upsampling_output = self.upsampling_layer(conv_output)
        return upsampling_output

# %%
# This class builds the Pyramid Pooling Module
# It builds the 4 feature maps and then concatenates all of them with the input
class PyramidPoolingModule(tf.keras.Model):
    
    def __init__(self):
        super(PyramidPoolingModule, self).__init__()
        self.block_red = PyramidFeatureMap('red', 64, 8, (1,1))
        self.block_yellow = PyramidFeatureMap('yellow', 64, 2, (2,2))
        self.block_blue = PyramidFeatureMap('blue', 64, 4, (3,3))
        self.block_green = PyramidFeatureMap('green', 64, 8, (6,6))
        
    def call(self,inputs):
        red_output = self.block_red(inputs)
        yellow_output = self.block_yellow(inputs)
        blue_output = self.block_blue(inputs)
        green_output = self.block_green(inputs)
        merged = concatenate([inputs, red_output, yellow_output, blue_output, green_output])
        return merged

# %%
# This block is for the last stage
# It gets the output of Pyramid Pooling Module and then performs convolution operation
# Pyramid Pooling -> Convolution -> Batch Normalization -> Softmax activation
class DecoderBlock(tf.keras.Model):
    
    def __init__(self, num_classes):
        super(DecoderBlock, self).__init__()
        self.pyramid_pooling_module = PyramidPoolingModule()
        self.convolution_layer = Convolution2D(num_classes, kernel_size = (3,3), padding = 'same')
        self.batch_norm_layer = BatchNormalization()
        self.activation = Activation('softmax')
    
    def call(self, inputs):
        merged = self.pyramid_pooling_module(inputs)
        conv_output = self.convolution_layer(merged)
        norm_output = self.batch_norm_layer(conv_output)
        output = self.activation(norm_output)
        return output

# %%
#This final class for the Model
class PSPNetModel(tf.keras.Model):
    
    def __init__(self, num_classes):
        super(PSPNetModel, self).__init__()
        self.resnet = ResNet50(weights='imagenet', include_top = False, input_shape = (128,128,3))
        for layer in self.resnet.layers:
            layer.trainable = False
        self.upsampling_encoder = UpSampling2D(size=(2,2), interpolation='bilinear')
        self.upsampling = UpSampling2D(size=(16,16), interpolation='bilinear')
        self.decoder = DecoderBlock(num_classes)
        
    def call(self, inputs):
        encoder_output = self.resnet(inputs)
        encoder_output = self.upsampling_encoder(encoder_output)
        decoder_output = self.decoder(encoder_output)
        final_output = self.upsampling(decoder_output)
        return final_output

# %%
from tensorflow.keras.layers import *
# SegmentationModel object
model = PSPNetModel(N_CLASSES)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
# Defining a loss object and an optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()
ckpt = tf.train.Checkpoint(step=tf.Variable(1), optimizer=optimizer, net=model)
manager = tf.train.CheckpointManager(ckpt, 'tf_ckpts/', max_to_keep=3)

# %%
# Define the metrics
train_loss = tf.keras.metrics.Mean('train_loss', dtype=tf.float32)
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy('train_accuracy')
test_loss = tf.keras.metrics.Mean('test_loss', dtype=tf.float32)
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy('test_accuracy')

# %%
# Reference -> https://github.com/junhoning/machine_learning_tutorial/blob/b20b8a10438ec3e62f08f920744cc8ea854cde91/Visualization%20%26%20TensorBoard/%5BTensorBoard%5D%20Semantic%20Segmentation.ipynb

@tf.function
def train_step(model, optimizer, x_train, y_train):
    with tf.GradientTape() as tape:
        predictions = model(x_train, training=True)
        loss = loss_object(y_train, predictions)
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    train_loss(loss)
    train_accuracy(y_train, predictions)
    
def train_and_checkpoint(model, manager, dataset, epoch):
    '''
    ckpt.restore(manager.latest_checkpoint)
    if manager.latest_checkpoint:
        print("Restored from {}".format(manager.latest_checkpoint))
    else:
        print("Initializing from scratch.")'''
    for (x_train, y_train) in dataset['train'].take(math.ceil(1403/16)):
        train_step(model, optimizer, x_train, y_train)
    ckpt.step.assign_add(1)
    save_path = manager.save()
    print("Saved checkpoint for epoch {}: {}".format(epoch, save_path))
    
@tf.function
def test_step(model, x_test, y_test):
    predictions = model(x_test)
    loss = loss_object(y_test, predictions)
    test_loss(loss)
    test_accuracy(y_test, predictions)
    return predictions

# %%
train_log_dir = 'logs/gradient_tape/train'
test_log_dir = 'logs/gradient_tape/test'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
test_summary_writer = tf.summary.create_file_writer(test_log_dir)

# %%
# This variable will help to save the best model if its performance increases after an epoch   
highest_accuracy = 0

# Training the model for 50 epochs
for epoch in range(50):

    print("Epoch ",epoch+1)
    
    # Getting the current time before starting the training
    # This will help to keep track of how much time an epoch took
    start = time.time()
    
    train_and_checkpoint(model, manager, dataset, epoch+1)
    
    # Saving the train loss and train accuracy metric for TensorBoard visualization
    with train_summary_writer.as_default():
        tf.summary.scalar('loss', train_loss.result(), step=ckpt.step.numpy())
        tf.summary.scalar('accuracy', train_accuracy.result(), step=ckpt.step.numpy())
    
    # Validation phase
    for (x_test, y_test) in dataset['val'].take(math.ceil(204/16)):
        pred = test_step(model, x_test, y_test)
    
    # Saving the validation loss and validation accuracy metric for Tensorboard visualization
    with test_summary_writer.as_default():
        tf.summary.scalar('loss', test_loss.result(), step=ckpt.step.numpy())
        tf.summary.scalar('accuracy', test_accuracy.result(), step=ckpt.step.numpy())
    
    # Calculating the time it took for the entire epoch to run
    print("Time taken ",time.time()-start)
    
    # Printing the metrics for the epoch
    template = 'Epoch {}, Loss: {:.3f}, Accuracy: {:.3f}, Val Loss: {:.3f}, Val Accuracy: {:.3f}'
    print (template.format(epoch+1,
                            train_loss.result(), 
                            train_accuracy.result()*100,
                            test_loss.result(), 
                            test_accuracy.result()*100))
    
    # If accuracy has increased in this epoch, updating the highest accuracy and saving the model
    if(test_accuracy.result().numpy()*100>highest_accuracy):
        print("Validation accuracy increased from {:.3f} to {:.3f}. Saving model weights.".format(highest_accuracy,test_accuracy.result().numpy()*100))
        highest_accuracy = test_accuracy.result().numpy()*100
        model.save_weights('pspnet_weights-epoch-{}.hdf5'.format(epoch+1))

    print('_'*80)

    # Reset metrics after every epoch
    train_loss.reset_states()
    test_loss.reset_states()
    train_accuracy.reset_states()
    test_accuracy.reset_states()
# Out:
# Epoch  1
# Saved checkpoint for epoch 1: tf_ckpts/ckpt-51
# Time taken  7.722947359085083
# Epoch 1, Loss: 0.818, Accuracy: 68.914, Val Loss: 0.901, Val Accuracy: 66.152
# Validation accuracy increased from 0.000 to 66.152. Saving model weights.
# ________________________________________________________________________________
# Epoch  2
# Saved checkpoint for epoch 2: tf_ckpts/ckpt-52
# Time taken  7.832643747329712
# Epoch 2, Loss: 0.816, Accuracy: 68.882, Val Loss: 1.012, Val Accuracy: 61.300
# ________________________________________________________________________________
# Epoch  3
# Saved checkpoint for epoch 3: tf_ckpts/ckpt-53
# Time taken  7.85509991645813
# Epoch 3, Loss: 0.815, Accuracy: 68.957, Val Loss: 1.041, Val Accuracy: 57.627
# ________________________________________________________________________________
# Epoch  4
# Saved checkpoint for epoch 4: tf_ckpts/ckpt-54
# Time taken  7.68192982673645
# Epoch 4, Loss: 0.817, Accuracy: 68.799, Val Loss: 1.160, Val Accuracy: 59.809
# ________________________________________________________________________________
# Epoch  5
# Saved checkpoint for epoch 5: tf_ckpts/ckpt-55
# Time taken  7.596909046173096
# Epoch 5, Loss: 0.810, Accuracy: 69.197, Val Loss: 0.877, Val Accuracy: 66.440
# Validation accuracy increased from 66.152 to 66.440. Saving model weights.
# ________________________________________________________________________________
# Epoch  6
# Saved checkpoint for epoch 6: tf_ckpts/ckpt-56
# Time taken  7.6176064014434814
# Epoch 6, Loss: 0.810, Accuracy: 69.051, Val Loss: 1.005, Val Accuracy: 64.634
# ________________________________________________________________________________
# Epoch  7
# Saved checkpoint for epoch 7: tf_ckpts/ckpt-57
# Time taken  7.634567737579346
# Epoch 7, Loss: 0.809, Accuracy: 69.010, Val Loss: 0.948, Val Accuracy: 65.748
# ________________________________________________________________________________
# Epoch  8
# Saved checkpoint for epoch 8: tf_ckpts/ckpt-58
# Time taken  7.8796515464782715
# Epoch 8, Loss: 0.807, Accuracy: 69.206, Val Loss: 0.988, Val Accuracy: 64.560
# ________________________________________________________________________________
# Epoch  9
# Saved checkpoint for epoch 9: tf_ckpts/ckpt-59
# Time taken  7.745513200759888
# Epoch 9, Loss: 0.807, Accuracy: 69.117, Val Loss: 0.997, Val Accuracy: 63.350
# ________________________________________________________________________________
# Epoch  10
# Saved checkpoint for epoch 10: tf_ckpts/ckpt-60
# Time taken  7.751079320907593
# Epoch 10, Loss: 0.807, Accuracy: 69.057, Val Loss: 0.966, Val Accuracy: 61.889
# ________________________________________________________________________________
# Epoch  11
# Saved checkpoint for epoch 11: tf_ckpts/ckpt-61
# Time taken  7.77427339553833
# Epoch 11, Loss: 0.803, Accuracy: 69.206, Val Loss: 0.988, Val Accuracy: 63.362
# ________________________________________________________________________________
# Epoch  12
# Saved checkpoint for epoch 12: tf_ckpts/ckpt-62
# Time taken  7.586764812469482
# Epoch 12, Loss: 0.805, Accuracy: 69.114, Val Loss: 1.034, Val Accuracy: 60.557
# ________________________________________________________________________________
# Epoch  13
# Saved checkpoint for epoch 13: tf_ckpts/ckpt-63
# Time taken  7.618704557418823
# Epoch 13, Loss: 0.802, Accuracy: 69.271, Val Loss: 0.893, Val Accuracy: 65.396
# ________________________________________________________________________________
# Epoch  14
# Saved checkpoint for epoch 14: tf_ckpts/ckpt-64
# Time taken  7.762380361557007
# Epoch 14, Loss: 0.800, Accuracy: 69.310, Val Loss: 0.944, Val Accuracy: 61.186
# ________________________________________________________________________________
# Epoch  15
# Saved checkpoint for epoch 15: tf_ckpts/ckpt-65
# Time taken  7.690219402313232
# Epoch 15, Loss: 0.801, Accuracy: 69.104, Val Loss: 0.914, Val Accuracy: 65.477
# ________________________________________________________________________________
# Epoch  16
# Saved checkpoint for epoch 16: tf_ckpts/ckpt-66
# Time taken  7.563236236572266
# Epoch 16, Loss: 0.798, Accuracy: 69.337, Val Loss: 0.936, Val Accuracy: 64.678
# ________________________________________________________________________________
# Epoch  17
# Saved checkpoint for epoch 17: tf_ckpts/ckpt-67
# Time taken  7.733087778091431
# Epoch 17, Loss: 0.799, Accuracy: 69.298, Val Loss: 0.894, Val Accuracy: 63.965
# ________________________________________________________________________________
# Epoch  18
# Saved checkpoint for epoch 18: tf_ckpts/ckpt-68
# Time taken  7.802278518676758
# Epoch 18, Loss: 0.804, Accuracy: 69.152, Val Loss: 0.929, Val Accuracy: 65.801
# ________________________________________________________________________________
# Epoch  19
# Saved checkpoint for epoch 19: tf_ckpts/ckpt-69
# Time taken  8.02064061164856
# Epoch 19, Loss: 0.798, Accuracy: 69.232, Val Loss: 1.000, Val Accuracy: 59.293
# ________________________________________________________________________________
# Epoch  20
# Saved checkpoint for epoch 20: tf_ckpts/ckpt-70
# Time taken  7.612626075744629
# Epoch 20, Loss: 0.793, Accuracy: 69.515, Val Loss: 0.981, Val Accuracy: 63.639
# ________________________________________________________________________________
# Epoch  21
# Saved checkpoint for epoch 21: tf_ckpts/ckpt-71
# Time taken  7.801541090011597
# Epoch 21, Loss: 0.792, Accuracy: 69.545, Val Loss: 1.022, Val Accuracy: 60.634
# ________________________________________________________________________________
# Epoch  22
# Saved checkpoint for epoch 22: tf_ckpts/ckpt-72
# Time taken  7.690798282623291
# Epoch 22, Loss: 0.797, Accuracy: 69.314, Val Loss: 0.919, Val Accuracy: 64.266
# ________________________________________________________________________________
# Epoch  23
# Saved checkpoint for epoch 23: tf_ckpts/ckpt-73
# Time taken  7.951421022415161
# Epoch 23, Loss: 0.793, Accuracy: 69.513, Val Loss: 1.145, Val Accuracy: 62.106
# ________________________________________________________________________________
# Epoch  24
# Saved checkpoint for epoch 24: tf_ckpts/ckpt-74
# Time taken  7.521837472915649
# Epoch 24, Loss: 0.794, Accuracy: 69.432, Val Loss: 1.184, Val Accuracy: 61.675
# ________________________________________________________________________________
# Epoch  25
# Saved checkpoint for epoch 25: tf_ckpts/ckpt-75
# Time taken  7.70028829574585
# Epoch 25, Loss: 0.792, Accuracy: 69.454, Val Loss: 0.914, Val Accuracy: 64.023
# ________________________________________________________________________________
# Epoch  26
# Saved checkpoint for epoch 26: tf_ckpts/ckpt-76
# Time taken  7.6761393547058105
# Epoch 26, Loss: 0.792, Accuracy: 69.468, Val Loss: 0.959, Val Accuracy: 62.222
# ________________________________________________________________________________
# Epoch  27
# Saved checkpoint for epoch 27: tf_ckpts/ckpt-77
# Time taken  7.680074691772461
# Epoch 27, Loss: 0.793, Accuracy: 69.491, Val Loss: 0.950, Val Accuracy: 65.987
# ________________________________________________________________________________
# Epoch  28
# Saved checkpoint for epoch 28: tf_ckpts/ckpt-78
# Time taken  8.158418893814087
# Epoch 28, Loss: 0.789, Accuracy: 69.569, Val Loss: 0.936, Val Accuracy: 66.417
# ________________________________________________________________________________
# Epoch  29
# Saved checkpoint for epoch 29: tf_ckpts/ckpt-79
# Time taken  7.796132802963257
# Epoch 29, Loss: 0.789, Accuracy: 69.484, Val Loss: 1.001, Val Accuracy: 63.996
# ________________________________________________________________________________
# Epoch  30
# Saved checkpoint for epoch 30: tf_ckpts/ckpt-80
# Time taken  7.909579277038574
# Epoch 30, Loss: 0.789, Accuracy: 69.512, Val Loss: 1.066, Val Accuracy: 58.640
# ________________________________________________________________________________
# Epoch  31
# Saved checkpoint for epoch 31: tf_ckpts/ckpt-81
# Time taken  7.798895597457886
# Epoch 31, Loss: 0.788, Accuracy: 69.641, Val Loss: 1.035, Val Accuracy: 61.363
# ________________________________________________________________________________
# Epoch  32
# Saved checkpoint for epoch 32: tf_ckpts/ckpt-82
# Time taken  7.772825241088867
# Epoch 32, Loss: 0.791, Accuracy: 69.434, Val Loss: 0.898, Val Accuracy: 64.678
# ________________________________________________________________________________
# Epoch  33
# Saved checkpoint for epoch 33: tf_ckpts/ckpt-83
# Time taken  7.7328736782073975
# Epoch 33, Loss: 0.787, Accuracy: 69.581, Val Loss: 1.036, Val Accuracy: 62.541
# ________________________________________________________________________________
# Epoch  34
# Saved checkpoint for epoch 34: tf_ckpts/ckpt-84
# Time taken  7.690364599227905
# Epoch 34, Loss: 0.783, Accuracy: 69.810, Val Loss: 0.912, Val Accuracy: 66.325
# ________________________________________________________________________________
# Epoch  35
# Saved checkpoint for epoch 35: tf_ckpts/ckpt-85
# Time taken  7.605969429016113
# Epoch 35, Loss: 0.785, Accuracy: 69.713, Val Loss: 0.949, Val Accuracy: 65.113
# ________________________________________________________________________________
# Epoch  36
# Saved checkpoint for epoch 36: tf_ckpts/ckpt-86
# Time taken  7.5365214347839355
# Epoch 36, Loss: 0.786, Accuracy: 69.660, Val Loss: 0.949, Val Accuracy: 64.428
# ________________________________________________________________________________
# Epoch  37
# Saved checkpoint for epoch 37: tf_ckpts/ckpt-87
# Time taken  7.63998818397522
# Epoch 37, Loss: 0.786, Accuracy: 69.703, Val Loss: 0.977, Val Accuracy: 62.917
# ________________________________________________________________________________
# Epoch  38
# Saved checkpoint for epoch 38: tf_ckpts/ckpt-88
# Time taken  7.633377313613892
# Epoch 38, Loss: 0.784, Accuracy: 69.669, Val Loss: 0.923, Val Accuracy: 66.158
# ________________________________________________________________________________
# Epoch  39
# Saved checkpoint for epoch 39: tf_ckpts/ckpt-89
# Time taken  7.696682691574097
# Epoch 39, Loss: 0.785, Accuracy: 69.716, Val Loss: 0.971, Val Accuracy: 62.695
# ________________________________________________________________________________
# Epoch  40
# Saved checkpoint for epoch 40: tf_ckpts/ckpt-90
# Time taken  7.6430344581604
# Epoch 40, Loss: 0.784, Accuracy: 69.703, Val Loss: 0.971, Val Accuracy: 63.878
# ________________________________________________________________________________
# Epoch  41
# Saved checkpoint for epoch 41: tf_ckpts/ckpt-91
# Time taken  7.595054864883423
# Epoch 41, Loss: 0.784, Accuracy: 69.694, Val Loss: 1.243, Val Accuracy: 53.386
# ________________________________________________________________________________
# Epoch  42
# Saved checkpoint for epoch 42: tf_ckpts/ckpt-92
# Time taken  7.70851731300354
# Epoch 42, Loss: 0.781, Accuracy: 69.830, Val Loss: 1.025, Val Accuracy: 58.837
# ________________________________________________________________________________
# Epoch  43
# Saved checkpoint for epoch 43: tf_ckpts/ckpt-93
# Time taken  7.566763162612915
# Epoch 43, Loss: 0.783, Accuracy: 69.738, Val Loss: 0.890, Val Accuracy: 66.135
# ________________________________________________________________________________
# Epoch  44
# Saved checkpoint for epoch 44: tf_ckpts/ckpt-94
# Time taken  7.726205348968506
# Epoch 44, Loss: 0.784, Accuracy: 69.749, Val Loss: 1.072, Val Accuracy: 55.223
# ________________________________________________________________________________
# Epoch  45
# Saved checkpoint for epoch 45: tf_ckpts/ckpt-95
# Time taken  7.887862205505371
# Epoch 45, Loss: 0.784, Accuracy: 69.699, Val Loss: 1.056, Val Accuracy: 60.159
# ________________________________________________________________________________
# Epoch  46
# Saved checkpoint for epoch 46: tf_ckpts/ckpt-96
# Time taken  7.864803791046143
# Epoch 46, Loss: 0.780, Accuracy: 69.888, Val Loss: 1.011, Val Accuracy: 62.575
# ________________________________________________________________________________
# Epoch  47
# Saved checkpoint for epoch 47: tf_ckpts/ckpt-97
# Time taken  8.068397998809814
# Epoch 47, Loss: 0.782, Accuracy: 69.642, Val Loss: 0.947, Val Accuracy: 61.403
# ________________________________________________________________________________
# Epoch  48
# Saved checkpoint for epoch 48: tf_ckpts/ckpt-98
# Time taken  7.591186285018921
# Epoch 48, Loss: 0.778, Accuracy: 69.938, Val Loss: 0.904, Val Accuracy: 65.157
# ________________________________________________________________________________
# Epoch  49
# Saved checkpoint for epoch 49: tf_ckpts/ckpt-99
# Time taken  7.768293857574463
# Epoch 49, Loss: 0.780, Accuracy: 69.785, Val Loss: 0.911, Val Accuracy: 65.700
# ________________________________________________________________________________
# Epoch  50
# Saved checkpoint for epoch 50: tf_ckpts/ckpt-100
# Time taken  7.454348802566528
# Epoch 50, Loss: 0.781, Accuracy: 69.685, Val Loss: 0.919, Val Accuracy: 64.248
# ________________________________________________________________________________

# %%
display(Image('Pretrained Encoder.png'))

# %%
# Loading the weights of the best model
model.load_weights('pspnet_weights-epoch-5.hdf5')

# %%
def predict(model,image_path):
    """
    This function will take the model which is going to be used to predict the image and the image path of 
    the input image as inputs and predict the mask
    It returns the true mask and predicted mask
    """
    # Getting the datapoint
    # This function will load the image and its annotation (mask) and return a dictionary.
    datapoint = parse_image(image_path)
    # Normalizing the resizing the datapoint
    input_image,image_mask = load_image_test(datapoint)
    # As the model takes input with 4 dimensions (batch_size, rows, columns, channels),
    # and the shape of the input image is (rows, columns, channels)
    # we will expand the first dimension so we will get the shape as  (1, rows, columns, channels)
    img = tf.expand_dims(input_image, 0)
    # Predicting the image by passing it to the model
    prediction = model(img)
    # The model will predict 8 outputs for each pixel
    # We have to get the maximum value out of it
    prediction = tf.argmax(prediction, axis=-1)
    prediction = tf.squeeze(prediction, axis = 0)
    pred_mask = tf.expand_dims(prediction, axis=-1)
    # Displaying the input image, true mask, predicted mask
    #display_sample([input_image, image_mask, pred_mask])
    return image_mask, pred_mask

# %%
# Reference -> https://github.com/saisandeepNSS/IDD_SemanticSegmentation

def IoU(y_i,y_pred):
    # This function calculates the mean Intersection over Union
    # Mean IoU = TP/(FN + TP + FP)
    # This list will save the IoU of all the classes
    IoUs = []
    # Defining the number of classes which the model has predicted
    n_classes = 8
    for c in range(n_classes):
        # Calculating the True Positives
        TP = np.sum((y_i == c)&(y_pred==c))
        # Calculating the False Positives
        FP = np.sum((y_i != c)&(y_pred==c))
        # Calculating the False Negatives
        FN = np.sum((y_i == c)&(y_pred!= c))
        # Calculating the IoU for the particular class
        IoU = TP/float(TP + FP + FN)
        # Printing the outputs
        # Uncomment the print statement below when you want to analyze the results for each class
        #print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        # Appending the IoU to the list as it mean needs to be calculated later
        if(math.isnan(IoU)):
            IoUs.append(0)
            continue
        IoUs.append(IoU)
    # Calculating the mean
    mIoU = np.mean(IoUs)
    #print("_________________")
    #print("Mean IoU: {:4.3f}".format(mIoU))
    return mIoU

# %% [markdown]
# ### Validation mIoU for PSPNet with Pretrained Encoder

# %%
img_val = dataset_path + 'leftImg8bit/val/'
val_paths = glob(img_val+'*/*_image.jpg')

# %%
mIoU = []
for path in val_paths:
    true_mask, pred_mask = predict(model,path)
    mIoU.append(IoU(true_mask, pred_mask))

# %%
print("Validation mIoU = ",sum(mIoU)/len(mIoU))
# Out:
# Validation mIoU =  0.2473203394937959

# %% [markdown]
# # Importing PSPNet from existing official models

# %%
#train_paths = glob(img_val+'*/*_image.jpg')

dataset_path = 'drive/My Drive/idd-lite/idd20k_lite/'
#img_train = dataset_path + 'leftImg8bit/train/'
#glob(img_train+'*/*_image.jpg')

# %%
import shutil
import tensorflow as tf
from tqdm import tqdm

img_train = dataset_path + 'leftImg8bit/train/'
train_paths = glob(img_train+'*/*_image.jpg')

for i in tqdm(train_paths):
    img = i.split('/')[-1]
    shutil.copy(i,'drive/My Drive/idd-lite/idd20k_lite/'+img)
    shutil.copy(i,'drive/My Drive/idd-lite/idd20k_lite/'+img)
    mask_path = tf.strings.regex_replace(i, "leftImg8bit", "gtFine")
    mask_path = tf.strings.regex_replace(mask_path, "_image.jpg", "_label.png")
    mask = img.split('_')[0]+'_label.png'
    shutil.copy(mask_path.numpy(),'drive/My Drive/idd-lite/idd20k_lite/'+mask)

# %%
img_val = dataset_path + 'leftImg8bit/val/'
val_paths = glob(img_val+'*/*_image.jpg')
#val_paths = glob('drive/My Drive/idd-lite/idd20k_lite/val')
for i in tqdm(val_paths):
    img = i.split('/')[-1]
    shutil.copy(i,'drive/My Drive/idd-lite/idd20k_lite/leftImg8bit/val/'+img)
    mask_path = tf.strings.regex_replace(i, "leftImg8bit", "gtFine")
    mask_path = tf.strings.regex_replace(mask_path, "_image.jpg", "_label.png")
    mask = img.split('_')[0]+'_label.png'
    shutil.copy(mask_path.numpy(),'drive/My Drive/idd-lite/idd20k_lite/leftImg8bit/val/'+mask)

# %%
# here dir_path is the route directory where all the images and segmentation maps are there
#train_path = "dataset_train"
dataset_path = 'drive/My Drive/idd-lite/idd20k_lite/'
train_path = 'drive/My Drive/idd-lite/idd20k_lite/leftImg8bit'
X_train = []
for i in os.listdir(train_path):
    X_train.append(i.split('.')[0])

val_path = "drive/My Drive/idd-lite/idd20k_lite/leftImg8bit"
X_test = []
for i in os.listdir(val_path):
    X_test.append(i.split('.')[0])

# %% [markdown]
# ```
# # This is formatted as code
#
# python 3
# keras >= 2.2.0 or tensorflow >= 1.13
# keras-applications >= 1.0.7, <=1.0.8
# image-classifiers == 1.0.*
# efficientnet == 1.0.*
#
#
#
# #!pip install q efficientnet==1.0
#
#
# import tensorflow
# print(tensorflow.__version__)
#
#
# import segmentation_models as sm
#
#
#
# import tensorflow as tf
#
#
#
#
# ```

# %%
#SM_FRAMEWORK = "keras" / 
#SM_FRAMEWORK = "tf.keras"

# %%
# !pip install q efficientnet==1.0

# %%
import keras

# %%
keras.__version__

# %%
! pip install -U segmentation-models

# %%
# %env SM_FRAMEWORK=tf.keras
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
# we are importing the pretrained unet from the segmentation models
# https://github.com/qubvel/segmentation_models
#SM_FRAMEWORK = keras / SM_FRAMEWORK=tf.keras
import segmentation_models as sm
import tensorflow.keras
#sm.set_framework('tf.keras')
tf.keras.backend.set_image_data_format('channels_last')
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from segmentation_models import PSPNet

# %%
# loading the unet model and using the resnet 34 and initilized weights with imagenet weights
# "classes" :different types of classes in the dataset
model = PSPNet('resnet34', encoder_weights='imagenet', classes=8, activation='softmax', input_shape=(192,192,3))
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85524480/85521592 [==============================] - 3s 0us/step

# %%
model.summary()

# %%
import imgaug.augmenters as iaa
# For the assignment choose any 4 augumentation techniques
# check the imgaug documentations for more augmentations
aug2 = iaa.Fliplr(1)
aug3 = iaa.Flipud(1)
aug4 = iaa.Emboss(alpha=(1), strength=1)
aug5 = iaa.DirectedEdgeDetect(alpha=(0.8), direction=(1.0))
aug6 = iaa.Sharpen(alpha=(1.0), lightness=(1.5))

# %%
def visualize(**images):
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        if i==1:
            plt.imshow(image, cmap='gray', vmax=1, vmin=0)
        else:
            plt.imshow(image)
    plt.show()
    
def normalize_image(img):
    img = img/255
    return img

class Dataset:
    
    CLASSES = [0,1,2,3,4,5,6,7]
    
    def __init__(self, directory, img_files,  classes):
        
        self.img_ids = img_files
        self.images_fps   = [os.path.join(directory, image_id.split('_')[0]+'_image.jpg') for image_id in self.img_ids]
        self.masks_fps    = [os.path.join(directory, image_id.split('_')[0]+'_label.png') for image_id in self.img_ids]
        self.class_values = [0,1,2,3,4,5,6,7]
        
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i], cv2.IMREAD_UNCHANGED)
        mask  = cv2.imread(self.masks_fps[i], cv2.IMREAD_UNCHANGED)
        image = np.float32(cv2.resize(image,(192,192)))
        mask = np.float32(cv2.resize(mask,(192,192)))
        mask[mask==255] = 7
        image = normalize_image(image)

        image_masks = [(mask == v) for v in self.class_values]
        image_mask = np.stack(image_masks, axis=-1).astype('float')

        a = np.random.uniform()
        if a<0.2:
            image = aug2.augment_image(image)
            image_mask = aug2.augment_image(image_mask)
        elif a<0.4:
            image = aug3.augment_image(image)
            image_mask = aug3.augment_image(image_mask)
        elif a<0.6:
            image = aug4.augment_image(image)
            image_mask = aug4.augment_image(image_mask)
        elif a<0.8:
            image = aug5.augment_image(image)
            image_mask = image_mask
        else:
            image = aug6.augment_image(image)
            image_mask = aug6.augment_image(image_mask)

        return image, image_mask
        
    def __len__(self):
        return len(self.img_ids)
    
    
class Dataloder(tf.keras.utils.Sequence):    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

    def __getitem__(self, i):       
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return tuple(batch)
    
    def __len__(self):
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# https://github.com/qubvel/segmentation_models
import segmentation_models as sm
from segmentation_models.metrics import iou_score
from segmentation_models import Unet

optim = tf.keras.optimizers.Adam(0.0001)

focal_loss = sm.losses.cce_dice_loss

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss 
# or total_loss = sm.losses.categorical_focal_dice_loss 

model.compile(optim, focal_loss, metrics=['accuracy',iou_score])

# %%
# Dataset for train images
CLASSES = ['Drivable', 'Non_Drivable', 'Living_things', 'Vehicles', 'Road_side_objects', 'Far_objects', 'Sky', 'Other']

train_path = 'drive/My Drive/idd-lite/idd20k_lite/leftImg8bit/train'
test_dataset = 'drive/My Drive/idd-lite/idd20k_lite/leftImg8bit/test'    
train_dataset = Dataset(train_path, X_train, classes=CLASSES)
test_dataset  = Dataset(val_path, X_test, classes=CLASSES)

# %%
train_dataloader = Dataloder(train_dataset, batch_size=16, shuffle=True)
test_dataloader = Dataloder(test_dataset, batch_size=16, shuffle=True)

print(train_dataloader[0][0].shape)
assert train_dataloader[0][0].shape == (16, 192, 192, 3)
assert train_dataloader[0][1].shape == (16, 192, 192, 8)

# %%
history = model.fit_generator(train_dataloader, steps_per_epoch=len(train_dataloader), epochs=50,\
                              validation_data=test_dataloader)

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
HEIGHT = 192
WIDTH = 192

def parse_image(img_path):
    """
    Load an image and its annotation (mask) and returning a dictionary.
    """
    # Reading the image
    image = tf.io.read_file(img_path)
    image = tf.image.decode_jpeg(image, channels=3)
    # For one Image path:
    # .../idd20k_lite/leftImg8bit/train/024541_image.jpg
    # Its corresponding annotation path is:
    # .../idd20k_lite/gtFine/train/024541_label.png
    mask_path = tf.strings.regex_replace(img_path, "leftImg8bit", "gtFine")
    mask_path = tf.strings.regex_replace(mask_path, "_image.jpg", "_label.png")
    # Reading the annotation file corresponding the image file
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    # In scene parsing, "not labeled" = 255
    # But it will mess with our N_CLASS = 7
    # Since 255 means the 255th class
    # Which doesn't exist
    mask = tf.where(mask==255, np.dtype('uint8').type(7), mask)
    # Note that we have to convert the new value (7)
    # With the same dtype than the tensor itself
    return {'image': image, 'segmentation_mask': mask}

# Reference -> https://www.tensorflow.org/api_docs/python/tf/cast
# Returns a Tensor same shape as given tensor and same type as dtype that is mentioned.

def normalize(input_image, input_mask):
    """
    Rescale the pixel values of the images between 0 and 1 compared to [0,255] originally.
    """
    input_image = tf.cast(input_image, tf.float32) / 255.0
    return input_image, input_mask

def load_image_test(datapoint):
    """
    Normalize and resize a test image and its annotation.
    Since this is for the test set, we don't need to apply any data augmentation technique.
    """
    input_image = tf.image.resize(datapoint['image'], (HEIGHT,WIDTH))
    input_mask = tf.image.resize(datapoint['segmentation_mask'], (HEIGHT,WIDTH))
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask

# %%
# Reference -> https://github.com/saisandeepNSS/IDD_SemanticSegmentation

def IoU(y_i,y_pred):
    # This function calculates the mean Intersection over Union
    # Mean IoU = TP/(FN + TP + FP)
    # This list will save the IoU of all the classes
    IoUs = []
    # Defining the number of classes which the model has predicted
    n_classes = 8
    for c in range(n_classes):
        # Calculating the True Positives
        TP = np.sum((y_i == c)&(y_pred==c))
        # Calculating the False Positives
        FP = np.sum((y_i != c)&(y_pred==c))
        # Calculating the False Negatives
        FN = np.sum((y_i == c)&(y_pred!= c))
        # Calculating the IoU for the particular class
        IoU = TP/float(TP + FP + FN)
        # Printing the outputs
        # Uncomment the print statement below when you want to analyze the results for each class
        #print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        # Appending the IoU to the list as it mean needs to be calculated later
        if(math.isnan(IoU)):
            IoUs.append(0)
            continue
        IoUs.append(IoU)
    # Calculating the mean
    mIoU = np.mean(IoUs)
    #print("_________________")
    #print("Mean IoU: {:4.3f}".format(mIoU))
    return mIoU

# %%
def predict(model,image_path):
    """
    This function will take the model which is going to be used to predict the image and the image path of 
    the input image as inputs and predict the mask
    It returns the true mask and predicted mask
    """
    # Getting the datapoint
    # This function will load the image and its annotation (mask) and return a dictionary.
    datapoint = parse_image(image_path)
    # Normalizing the resizing the datapoint
    input_image,image_mask = load_image_test(datapoint)
    # As the model takes input with 4 dimensions (batch_size, rows, columns, channels),
    # and the shape of the input image is (rows, columns, channels)
    # we will expand the first dimension so we will get the shape as  (1, rows, columns, channels)
    img = tf.expand_dims(input_image, 0)
    # Predicting the image by passing it to the model
    prediction = model.predict_on_batch(img)
    # The model will predict 8 outputs for each pixel
    # We have to get the maximum value out of it
    prediction = tf.argmax(prediction, axis=-1)
    prediction = tf.squeeze(prediction, axis = 0)
    pred_mask = tf.expand_dims(prediction, axis=-1)
    # Displaying the input image, true mask, predicted mask
    #display_sample([input_image, image_mask, pred_mask])
    return image_mask, pred_mask

# %% [markdown]
# ### Validation mIoU for PSPNet imported model

# %%
img_val = dataset_path + 'leftImg8bit/val/'
val_paths = glob(img_val+'*/*_image.jpg')

# %%
mIoU = []
for path in val_paths:
    true_mask, pred_mask = predict(model,path)
    mIoU.append(IoU(true_mask, pred_mask))

# %%
print("Validation mIoU Score : ",sum(mIoU)/len(mIoU))

# %% [markdown]
# # Observations

# %%
from prettytable import PrettyTable

# Representing results in a table
pt = PrettyTable()

pt.field_names = ["Model", "Highest Train Accuracy", "Highest Validation Accuracy", "Validation mIoU"]
pt.add_row(["PSPNet (from Scratch)",'89.76 %','80.80 %',0.43338])
pt.add_row(["PSPNet with a Pretrained Encoder",'69.438 %','66.919 %',0.24952])
pt.add_row(["PSPNet (from official models)",'89.91 %','83.08 %', 0.36370])
print(pt)

# %% [markdown]
# * The best results are found using PSPNet from Scratch model.
# * When we train PSPNet using a pretrained encoder, the results fluctuate a lot and the validation mIoU is very low as well.
# * While using the official model, we get a high validation accuracy, but the validation mIoU score is low.
